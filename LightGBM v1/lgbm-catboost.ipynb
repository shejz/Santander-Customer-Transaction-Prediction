# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error,roc_auc_score
from sklearn.model_selection import StratifiedKFold,train_test_split
from sklearn.preprocessing import StandardScaler
import lightgbm as lgb

# %% [markdown]
# ## Load Data

# %%
#Load data
train = pd.read_csv('/content/train.csv.zip')
test = pd.read_csv('/content/test.csv.zip')

# %%
## Use no scaling data to train LGBM
train_features = train.drop(['target','ID_code'], axis = 1)
test_features = test.drop(['ID_code'],axis = 1)
train_target = train['target']

# %%
train_all = pd.concat((train_features,test_features),axis = 0)

# %%
for f in train_all.columns:
    train_all[f+'_duplicate'] = train_all.duplicated(f,False).astype(int)
train_all['count_total_all']=train_all.iloc[:,200:400].sum(axis=1)

# %%
train_features = train_all.iloc[:200000]
test_features = train_all.iloc[200000:400000]

# %%
def add_noise(series, noise_level):
    return series * (1 + noise_level * np.random.randn(len(series)))
def target_encode(trn_series=None, 
                  tst_series=None, 
                  target=None, 
                  min_samples_leaf=1, 
                  smoothing=1,
                  noise_level=0):
   
    assert len(trn_series) == len(target)
    assert trn_series.name == tst_series.name
    trn_series = round(trn_series,1)
    tst_series = round(tst_series,1)
    temp = pd.concat([trn_series, target], axis=1)
    # Compute target mean 
    averages = temp.groupby(by=trn_series.name)[target.name].agg(["mean", "count"])
    # Compute smoothing
    smoothing = 1 / (1 + np.exp(-(averages["count"] - min_samples_leaf) / smoothing))
    # Apply average function to all target data
    prior = target.mean()
    # The bigger the count the less full_avg is taken into account
    averages[target.name] = prior * (1 - smoothing) + averages["mean"] * smoothing
    averages.drop(["mean", "count"], axis=1, inplace=True)
    # Apply averages to trn and tst series
    ft_trn_series = pd.merge(
        trn_series.to_frame(trn_series.name),
        averages.reset_index().rename(columns={'index': target.name, target.name: 'average'}),
        on=trn_series.name,
        how='left')['average'].rename(trn_series.name + '_mean').fillna(prior)
    # pd.merge does not keep the index so restore it
    ft_trn_series.index = trn_series.index 
    ft_tst_series = pd.merge(
        tst_series.to_frame(tst_series.name),
        averages.reset_index().rename(columns={'index': target.name, target.name: 'average'}),
        on=tst_series.name,
        how='left')['average'].rename(trn_series.name + '_mean').fillna(prior)
    # pd.merge does not keep the index so restore it
    ft_tst_series.index = tst_series.index
    return add_noise(ft_trn_series, noise_level), add_noise(ft_tst_series, noise_level)

# %%
train_features.shape, test_features.shape, train_target.shape
# Out:
# ((200000, 401), (200000, 401), (200000,))

# %%
# Number of K-fold Splits
n_splits = 7 

splits = list(StratifiedKFold(n_splits=n_splits, shuffle=True).split(train_features, train_target))
splits[:3]
# Out:
# [(array([     0,      1,      2, ..., 199996, 199998, 199999]),
#   array([     6,      9,     10, ..., 199987, 199990, 199997])),
#  (array([     0,      1,      2, ..., 199997, 199998, 199999]),
#   array([     4,     18,     32, ..., 199972, 199978, 199985])),
#  (array([     0,      1,      2, ..., 199996, 199997, 199998]),
#   array([    16,     17,     20, ..., 199973, 199992, 199999]))]

# %%
cat_params = {
    'learning_rate':0.01,
    'max_depth':2,
    'eval_metric': 'AUC',
    'bootstrap_type': 'Bayesian',
    'bagging_temperature': 1,
    'objective': 'Logloss',
    'od_type': 'Iter',
    'l2_leaf_reg': 2,
    'allow_writing_files': False}

# %%
from catboost import CatBoostClassifier
oof_cb = np.zeros(len(train_features))
predictions_cb = np.zeros(len(test))

for i, (train_idx, valid_idx) in enumerate(splits):  
    print(f'Fold {i + 1}')
    x_train = np.array(train_features)
    y_train = np.array(train_target)
    trn_x = x_train[train_idx.astype(int)]
    trn_y = y_train[train_idx.astype(int)]
    val_x = x_train[valid_idx.astype(int)]
    val_y = y_train[valid_idx.astype(int)]
    
    num_round = 100000
    clf = CatBoostClassifier( num_round, task_type='GPU', early_stopping_rounds=1000,**cat_params,)
    clf.fit(trn_x, trn_y, eval_set=(val_x, val_y), cat_features=[], use_best_model=True, verbose=500)
    
    oof_cb[valid_idx] = clf.predict_proba(val_x)[:,1]

    predictions_cb += clf.predict_proba(test_features)[:,1] / 5

print("CV score: {:<8.5f}".format(roc_auc_score(train_target, oof_cb)))
# Out:
# Fold 1
# 0:	learn: 0.5336323	test: 0.5321515	best: 0.5321515 (0)	total: 11.3ms	remaining: 18m 49s
# 500:	learn: 0.7764010	test: 0.7620753	best: 0.7620753 (500)	total: 4.66s	remaining: 15m 25s
# 1000:	learn: 0.8103403	test: 0.7982503	best: 0.7982503 (1000)	total: 9.11s	remaining: 15m
# 1500:	learn: 0.8315673	test: 0.8208628	best: 0.8208628 (1500)	total: 13.3s	remaining: 14m 32s
# 2000:	learn: 0.8460483	test: 0.8359794	best: 0.8359794 (2000)	total: 17.6s	remaining: 14m 24s
# 2500:	learn: 0.8563699	test: 0.8463387	best: 0.8463387 (2500)	total: 21.8s	remaining: 14m 11s
# 3000:	learn: 0.8642739	test: 0.8541797	best: 0.8541797 (3000)	total: 26.1s	remaining: 14m 4s
# 3500:	learn: 0.8705668	test: 0.8604226	best: 0.8604226 (3500)	total: 30.4s	remaining: 13m 57s
# 4000:	learn: 0.8758339	test: 0.8656713	best: 0.8656713 (4000)	total: 35s	remaining: 14m
# 4500:	learn: 0.8803684	test: 0.8699176	best: 0.8699176 (4500)	total: 39.5s	remaining: 13m 59s
# 5000:	learn: 0.8841513	test: 0.8736697	best: 0.8736697 (5000)	total: 44.3s	remaining: 14m 1s
# 5500:	learn: 0.8873640	test: 0.8768702	best: 0.8768702 (5500)	total: 48.7s	remaining: 13m 57s
# 6000:	learn: 0.8902061	test: 0.8796760	best: 0.8796760 (6000)	total: 53s	remaining: 13m 50s
# 6500:	learn: 0.8927342	test: 0.8821578	best: 0.8821578 (6500)	total: 57.3s	remaining: 13m 44s
# 7000:	learn: 0.8950514	test: 0.8843326	best: 0.8843391 (6998)	total: 1m 1s	remaining: 13m 39s
# 7500:	learn: 0.8970050	test: 0.8862062	best: 0.8862062 (7500)	total: 1m 6s	remaining: 13m 35s
# 8000:	learn: 0.8988460	test: 0.8879767	best: 0.8879767 (8000)	total: 1m 10s	remaining: 13m 28s
# 8500:	learn: 0.9004579	test: 0.8895077	best: 0.8895077 (8500)	total: 1m 14s	remaining: 13m 22s
# 9000:	learn: 0.9020578	test: 0.8909346	best: 0.8909346 (9000)	total: 1m 18s	remaining: 13m 17s
# 9500:	learn: 0.9034154	test: 0.8921463	best: 0.8921463 (9500)	total: 1m 23s	remaining: 13m 11s
# 10000:	learn: 0.9046624	test: 0.8932753	best: 0.8932753 (10000)	total: 1m 27s	remaining: 13m 7s
# 10500:	learn: 0.9058257	test: 0.8943756	best: 0.8943756 (10500)	total: 1m 31s	remaining: 13m 2s
# 11000:	learn: 0.9069278	test: 0.8953506	best: 0.8953506 (11000)	total: 1m 36s	remaining: 13m
# 11500:	learn: 0.9079949	test: 0.8963028	best: 0.8963028 (11500)	total: 1m 41s	remaining: 12m 58s
# 12000:	learn: 0.9089975	test: 0.8971587	best: 0.8971639 (11996)	total: 1m 45s	remaining: 12m 52s
# 12500:	learn: 0.9098862	test: 0.8978894	best: 0.8978898 (12499)	total: 1m 49s	remaining: 12m 47s
# 13000:	learn: 0.9107515	test: 0.8987114	best: 0.8987114 (13000)	total: 1m 53s	remaining: 12m 42s
# 13500:	learn: 0.9115396	test: 0.8993878	best: 0.8993878 (13500)	total: 1m 58s	remaining: 12m 39s
# 14000:	learn: 0.9122984	test: 0.9000135	best: 0.9000135 (14000)	total: 2m 3s	remaining: 12m 37s
# 14500:	learn: 0.9130533	test: 0.9006366	best: 0.9006389 (14497)	total: 2m 7s	remaining: 12m 34s
# 15000:	learn: 0.9137188	test: 0.9011548	best: 0.9011571 (14999)	total: 2m 12s	remaining: 12m 29s
# 15500:	learn: 0.9144012	test: 0.9017058	best: 0.9017069 (15499)	total: 2m 16s	remaining: 12m 23s
# 16000:	learn: 0.9150104	test: 0.9022029	best: 0.9022066 (15997)	total: 2m 20s	remaining: 12m 18s
# 16500:	learn: 0.9155985	test: 0.9026763	best: 0.9026763 (16500)	total: 2m 24s	remaining: 12m 13s
# 17000:	learn: 0.9161885	test: 0.9031230	best: 0.9031240 (16999)	total: 2m 29s	remaining: 12m 8s
# 17500:	learn: 0.9167292	test: 0.9035175	best: 0.9035175 (17500)	total: 2m 33s	remaining: 12m 4s
# 18000:	learn: 0.9172635	test: 0.9039513	best: 0.9039513 (18000)	total: 2m 38s	remaining: 12m 1s
# 18500:	learn: 0.9177577	test: 0.9043148	best: 0.9043148 (18500)	total: 2m 42s	remaining: 11m 57s
# 19000:	learn: 0.9182487	test: 0.9046575	best: 0.9046593 (18998)	total: 2m 47s	remaining: 11m 54s
# 19500:	learn: 0.9186879	test: 0.9049322	best: 0.9049329 (19499)	total: 2m 52s	remaining: 11m 51s
# 20000:	learn: 0.9191416	test: 0.9052759	best: 0.9052759 (20000)	total: 2m 57s	remaining: 11m 48s
# 20500:	learn: 0.9195738	test: 0.9055607	best: 0.9055641 (20487)	total: 3m 1s	remaining: 11m 45s
# 21000:	learn: 0.9199747	test: 0.9058418	best: 0.9058418 (21000)	total: 3m 6s	remaining: 11m 41s
# 21500:	learn: 0.9203862	test: 0.9061263	best: 0.9061263 (21500)	total: 3m 11s	remaining: 11m 37s
# 22000:	learn: 0.9207805	test: 0.9063842	best: 0.9063852 (21998)	total: 3m 15s	remaining: 11m 33s
# 22500:	learn: 0.9211853	test: 0.9066763	best: 0.9066763 (22500)	total: 3m 20s	remaining: 11m 28s
# 23000:	learn: 0.9215664	test: 0.9069473	best: 0.9069473 (23000)	total: 3m 24s	remaining: 11m 24s
# 23500:	learn: 0.9219220	test: 0.9071589	best: 0.9071597 (23484)	total: 3m 28s	remaining: 11m 19s
# 24000:	learn: 0.9222801	test: 0.9073775	best: 0.9073775 (24000)	total: 3m 33s	remaining: 11m 14s
# 24500:	learn: 0.9226154	test: 0.9076020	best: 0.9076020 (24500)	total: 3m 37s	remaining: 11m 9s
# 25000:	learn: 0.9229304	test: 0.9077978	best: 0.9077978 (25000)	total: 3m 41s	remaining: 11m 4s
# 25500:	learn: 0.9232543	test: 0.9080026	best: 0.9080026 (25500)	total: 3m 46s	remaining: 11m
# 26000:	learn: 0.9235617	test: 0.9081816	best: 0.9081816 (26000)	total: 3m 50s	remaining: 10m 57s
# 26500:	learn: 0.9238726	test: 0.9083373	best: 0.9083390 (26498)	total: 3m 55s	remaining: 10m 53s
# 27000:	learn: 0.9241825	test: 0.9085353	best: 0.9085383 (26979)	total: 3m 59s	remaining: 10m 47s
# 27500:	learn: 0.9244836	test: 0.9087098	best: 0.9087120 (27488)	total: 4m 3s	remaining: 10m 42s
# 28000:	learn: 0.9247851	test: 0.9088533	best: 0.9088558 (27978)	total: 4m 7s	remaining: 10m 37s
# 28500:	learn: 0.9250699	test: 0.9090226	best: 0.9090258 (28496)	total: 4m 12s	remaining: 10m 32s
# 29000:	learn: 0.9253353	test: 0.9091578	best: 0.9091635 (28974)	total: 4m 16s	remaining: 10m 27s
# 29500:	learn: 0.9256001	test: 0.9092855	best: 0.9092863 (29497)	total: 4m 20s	remaining: 10m 23s
# 30000:	learn: 0.9258702	test: 0.9093931	best: 0.9093937 (29999)	total: 4m 25s	remaining: 10m 19s
# 30500:	learn: 0.9261236	test: 0.9094905	best: 0.9094905 (30499)	total: 4m 30s	remaining: 10m 15s
# 31000:	learn: 0.9263752	test: 0.9096031	best: 0.9096057 (30983)	total: 4m 34s	remaining: 10m 11s
# 31500:	learn: 0.9266312	test: 0.9097391	best: 0.9097399 (31498)	total: 4m 39s	remaining: 10m 7s
# 32000:	learn: 0.9268909	test: 0.9098508	best: 0.9098511 (31998)	total: 4m 44s	remaining: 10m 3s
# 32500:	learn: 0.9271520	test: 0.9099618	best: 0.9099618 (32500)	total: 4m 49s	remaining: 10m
# 33000:	learn: 0.9274043	test: 0.9100600	best: 0.9100615 (32977)	total: 4m 53s	remaining: 9m 56s
# 33500:	learn: 0.9276402	test: 0.9101495	best: 0.9101501 (33498)	total: 4m 58s	remaining: 9m 52s
# 34000:	learn: 0.9278728	test: 0.9102529	best: 0.9102548 (33989)	total: 5m 3s	remaining: 9m 48s
# 34500:	learn: 0.9281277	test: 0.9103431	best: 0.9103431 (34500)	total: 5m 7s	remaining: 9m 44s
# 35000:	learn: 0.9283560	test: 0.9104502	best: 0.9104508 (34998)	total: 5m 12s	remaining: 9m 40s
# 35500:	learn: 0.9285934	test: 0.9105679	best: 0.9105691 (35498)	total: 5m 16s	remaining: 9m 35s
# 36000:	learn: 0.9288219	test: 0.9106580	best: 0.9106580 (35988)	total: 5m 21s	remaining: 9m 31s
# 36500:	learn: 0.9290583	test: 0.9107695	best: 0.9107720 (36487)	total: 5m 26s	remaining: 9m 27s
# 37000:	learn: 0.9292802	test: 0.9108565	best: 0.9108570 (36996)	total: 5m 31s	remaining: 9m 23s
# 37500:	learn: 0.9295061	test: 0.9109376	best: 0.9109430 (37423)	total: 5m 35s	remaining: 9m 19s
# 38000:	learn: 0.9297255	test: 0.9109815	best: 0.9109877 (37964)	total: 5m 40s	remaining: 9m 15s
# 38500:	learn: 0.9299262	test: 0.9110229	best: 0.9110229 (38500)	total: 5m 44s	remaining: 9m 11s
# 39000:	learn: 0.9301515	test: 0.9110910	best: 0.9110910 (39000)	total: 5m 49s	remaining: 9m 7s
# 39500:	learn: 0.9303796	test: 0.9111553	best: 0.9111592 (39490)	total: 5m 54s	remaining: 9m 2s
# 40000:	learn: 0.9305985	test: 0.9112161	best: 0.9112208 (39989)	total: 5m 59s	remaining: 8m 58s
# 40500:	learn: 0.9308082	test: 0.9112927	best: 0.9112927 (40500)	total: 6m 3s	remaining: 8m 54s
# 41000:	learn: 0.9310275	test: 0.9113472	best: 0.9113502 (40977)	total: 6m 8s	remaining: 8m 50s
# 41500:	learn: 0.9312310	test: 0.9113764	best: 0.9113873 (41371)	total: 6m 13s	remaining: 8m 45s
# 42000:	learn: 0.9314428	test: 0.9114053	best: 0.9114061 (41991)	total: 6m 17s	remaining: 8m 41s
# 42500:	learn: 0.9316494	test: 0.9114650	best: 0.9114655 (42499)	total: 6m 22s	remaining: 8m 37s
# 43000:	learn: 0.9318454	test: 0.9115161	best: 0.9115185 (42968)	total: 6m 27s	remaining: 8m 33s
# 43500:	learn: 0.9320606	test: 0.9115705	best: 0.9115725 (43472)	total: 6m 31s	remaining: 8m 28s
# 44000:	learn: 0.9322690	test: 0.9116408	best: 0.9116421 (43999)	total: 6m 36s	remaining: 8m 24s
# 44500:	learn: 0.9324703	test: 0.9116817	best: 0.9116824 (44485)	total: 6m 41s	remaining: 8m 20s
# 45000:	learn: 0.9326614	test: 0.9117243	best: 0.9117243 (45000)	total: 6m 45s	remaining: 8m 16s
# 45500:	learn: 0.9328550	test: 0.9117671	best: 0.9117704 (45477)	total: 6m 50s	remaining: 8m 12s
# 46000:	learn: 0.9330592	test: 0.9118377	best: 0.9118385 (45995)	total: 6m 55s	remaining: 8m 7s
# 46500:	learn: 0.9332483	test: 0.9118974	best: 0.9118980 (46490)	total: 7m	remaining: 8m 3s
# 47000:	learn: 0.9334540	test: 0.9119558	best: 0.9119583 (46963)	total: 7m 4s	remaining: 7m 58s
# 47500:	learn: 0.9336389	test: 0.9119933	best: 0.9119982 (47418)	total: 7m 9s	remaining: 7m 54s
# 48000:	learn: 0.9338310	test: 0.9120045	best: 0.9120047 (47998)	total: 7m 14s	remaining: 7m 50s
# 48500:	learn: 0.9340170	test: 0.9120159	best: 0.9120231 (48265)	total: 7m 18s	remaining: 7m 45s
# 49000:	learn: 0.9342017	test: 0.9120662	best: 0.9120662 (49000)	total: 7m 23s	remaining: 7m 41s
# 49500:	learn: 0.9343930	test: 0.9120587	best: 0.9120677 (49346)	total: 7m 27s	remaining: 7m 36s
# 50000:	learn: 0.9345903	test: 0.9120969	best: 0.9121000 (49954)	total: 7m 32s	remaining: 7m 32s
# 50500:	learn: 0.9347920	test: 0.9121422	best: 0.9121431 (50493)	total: 7m 36s	remaining: 7m 27s
# 51000:	learn: 0.9349864	test: 0.9121448	best: 0.9121560 (50859)	total: 7m 41s	remaining: 7m 22s
# 51500:	learn: 0.9351749	test: 0.9121839	best: 0.9121843 (51499)	total: 7m 45s	remaining: 7m 18s
# 52000:	learn: 0.9353569	test: 0.9121960	best: 0.9121992 (51991)	total: 7m 50s	remaining: 7m 14s
# 52500:	learn: 0.9355400	test: 0.9122152	best: 0.9122162 (52172)	total: 7m 55s	remaining: 7m 10s
# 53000:	learn: 0.9357104	test: 0.9122396	best: 0.9122443 (52932)	total: 8m	remaining: 7m 5s
# 53500:	learn: 0.9358972	test: 0.9122993	best: 0.9123015 (53382)	total: 8m 4s	remaining: 7m 1s
# 54000:	learn: 0.9360856	test: 0.9123245	best: 0.9123260 (53974)	total: 8m 9s	remaining: 6m 56s
# 54500:	learn: 0.9362631	test: 0.9123521	best: 0.9123583 (54479)	total: 8m 13s	remaining: 6m 52s
# 55000:	learn: 0.9364392	test: 0.9123562	best: 0.9123645 (54883)	total: 8m 18s	remaining: 6m 47s
# 55500:	learn: 0.9366105	test: 0.9123648	best: 0.9123711 (55348)	total: 8m 22s	remaining: 6m 43s
# 56000:	learn: 0.9367934	test: 0.9123605	best: 0.9123743 (55543)	total: 8m 27s	remaining: 6m 38s
# 56500:	learn: 0.9369773	test: 0.9123959	best: 0.9123976 (56484)	total: 8m 31s	remaining: 6m 33s
# 57000:	learn: 0.9371593	test: 0.9124360	best: 0.9124365 (56929)	total: 8m 35s	remaining: 6m 28s
# 57500:	learn: 0.9373201	test: 0.9124539	best: 0.9124550 (57441)	total: 8m 40s	remaining: 6m 24s
# 58000:	learn: 0.9374962	test: 0.9124610	best: 0.9124619 (57999)	total: 8m 44s	remaining: 6m 20s
# 58500:	learn: 0.9376714	test: 0.9124854	best: 0.9124868 (58491)	total: 8m 49s	remaining: 6m 15s
# 59000:	learn: 0.9378501	test: 0.9125098	best: 0.9125118 (58975)	total: 8m 53s	remaining: 6m 10s
# 59500:	learn: 0.9380329	test: 0.9125327	best: 0.9125330 (59496)	total: 8m 57s	remaining: 6m 6s
# 60000:	learn: 0.9382144	test: 0.9125509	best: 0.9125580 (59919)	total: 9m 2s	remaining: 6m 1s
# 60500:	learn: 0.9383833	test: 0.9125634	best: 0.9125730 (60411)	total: 9m 6s	remaining: 5m 56s
# 61000:	learn: 0.9385522	test: 0.9125925	best: 0.9125925 (61000)	total: 9m 10s	remaining: 5m 52s
# 61500:	learn: 0.9387255	test: 0.9125872	best: 0.9125941 (61279)	total: 9m 15s	remaining: 5m 47s
# 62000:	learn: 0.9388993	test: 0.9126020	best: 0.9126074 (61940)	total: 9m 20s	remaining: 5m 43s
# 62500:	learn: 0.9390737	test: 0.9126175	best: 0.9126177 (62499)	total: 9m 24s	remaining: 5m 38s
# 63000:	learn: 0.9392489	test: 0.9126418	best: 0.9126449 (62889)	total: 9m 28s	remaining: 5m 34s
# 63500:	learn: 0.9394252	test: 0.9126539	best: 0.9126548 (63469)	total: 9m 33s	remaining: 5m 29s
# 64000:	learn: 0.9395886	test: 0.9126642	best: 0.9126679 (63707)	total: 9m 37s	remaining: 5m 24s
# 64500:	learn: 0.9397486	test: 0.9126877	best: 0.9126928 (64442)	total: 9m 41s	remaining: 5m 20s
# 65000:	learn: 0.9399104	test: 0.9126815	best: 0.9126928 (64442)	total: 9m 46s	remaining: 5m 15s
# 65500:	learn: 0.9400708	test: 0.9127068	best: 0.9127103 (65491)	total: 9m 50s	remaining: 5m 11s
# 66000:	learn: 0.9402313	test: 0.9126933	best: 0.9127103 (65491)	total: 9m 55s	remaining: 5m 6s
# bestTest = 0.912710309
# bestIteration = 65491
# Shrink model to first 65492 iterations.
# Fold 2
# 0:	learn: 0.5257849	test: 0.5197976	best: 0.5197976 (0)	total: 10.3ms	remaining: 17m 10s
# 500:	learn: 0.7743387	test: 0.7623654	best: 0.7623654 (500)	total: 4.63s	remaining: 15m 19s
# 1000:	learn: 0.8102421	test: 0.7996304	best: 0.7996304 (1000)	total: 9.3s	remaining: 15m 19s
# 1500:	learn: 0.8311872	test: 0.8213414	best: 0.8213414 (1500)	total: 14s	remaining: 15m 16s
# 2000:	learn: 0.8462709	test: 0.8367738	best: 0.8367738 (2000)	total: 18.7s	remaining: 15m 15s
# 2500:	learn: 0.8564467	test: 0.8470587	best: 0.8470590 (2498)	total: 23.1s	remaining: 15m
# 3000:	learn: 0.8642723	test: 0.8548857	best: 0.8548857 (3000)	total: 27.6s	remaining: 14m 51s
# 3500:	learn: 0.8707238	test: 0.8614202	best: 0.8614278 (3499)	total: 32.1s	remaining: 14m 44s
# 4000:	learn: 0.8758066	test: 0.8666068	best: 0.8666068 (4000)	total: 36.5s	remaining: 14m 36s
# 4500:	learn: 0.8800967	test: 0.8709979	best: 0.8709979 (4500)	total: 40.6s	remaining: 14m 21s
# 5000:	learn: 0.8837940	test: 0.8745684	best: 0.8745707 (4999)	total: 44.9s	remaining: 14m 13s
# 5500:	learn: 0.8870913	test: 0.8778045	best: 0.8778045 (5500)	total: 49.5s	remaining: 14m 9s
# 6000:	learn: 0.8900400	test: 0.8806859	best: 0.8806859 (6000)	total: 54.1s	remaining: 14m 7s
# 6500:	learn: 0.8924368	test: 0.8830312	best: 0.8830315 (6497)	total: 58.7s	remaining: 14m 4s
# 7000:	learn: 0.8946266	test: 0.8850942	best: 0.8850948 (6999)	total: 1m 3s	remaining: 14m
# 7500:	learn: 0.8966661	test: 0.8870730	best: 0.8870730 (7500)	total: 1m 8s	remaining: 13m 58s
# 8000:	learn: 0.8984855	test: 0.8887422	best: 0.8887422 (8000)	total: 1m 12s	remaining: 13m 55s
# 8500:	learn: 0.9001976	test: 0.8903832	best: 0.8903832 (8500)	total: 1m 17s	remaining: 13m 55s
# 9000:	learn: 0.9016827	test: 0.8916895	best: 0.8916895 (9000)	total: 1m 22s	remaining: 13m 52s
# 9500:	learn: 0.9030719	test: 0.8929572	best: 0.8929572 (9500)	total: 1m 26s	remaining: 13m 47s
# 10000:	learn: 0.9044132	test: 0.8941872	best: 0.8941878 (9999)	total: 1m 31s	remaining: 13m 41s
# 10500:	learn: 0.9056960	test: 0.8952370	best: 0.8952387 (10499)	total: 1m 35s	remaining: 13m 37s
# 11000:	learn: 0.9068561	test: 0.8961509	best: 0.8961509 (11000)	total: 1m 40s	remaining: 13m 33s
# 11500:	learn: 0.9078529	test: 0.8970255	best: 0.8970255 (11500)	total: 1m 45s	remaining: 13m 28s
# 12000:	learn: 0.9088413	test: 0.8978862	best: 0.8978865 (11999)	total: 1m 49s	remaining: 13m 24s
# 12500:	learn: 0.9097599	test: 0.8986626	best: 0.8986626 (12500)	total: 1m 53s	remaining: 13m 17s
# 13000:	learn: 0.9106157	test: 0.8993005	best: 0.8993028 (12997)	total: 1m 58s	remaining: 13m 10s
# 13500:	learn: 0.9114353	test: 0.8999899	best: 0.8999927 (13499)	total: 2m 2s	remaining: 13m 3s
# 14000:	learn: 0.9122253	test: 0.9006506	best: 0.9006506 (13999)	total: 2m 6s	remaining: 12m 59s
# 14500:	learn: 0.9129219	test: 0.9012026	best: 0.9012026 (14500)	total: 2m 11s	remaining: 12m 54s
# 15000:	learn: 0.9135990	test: 0.9017348	best: 0.9017352 (14993)	total: 2m 16s	remaining: 12m 51s
# 15500:	learn: 0.9142874	test: 0.9022279	best: 0.9022307 (15497)	total: 2m 20s	remaining: 12m 44s
# 16000:	learn: 0.9148924	test: 0.9026661	best: 0.9026661 (15995)	total: 2m 24s	remaining: 12m 38s
# 16500:	learn: 0.9155107	test: 0.9031668	best: 0.9031686 (16497)	total: 2m 28s	remaining: 12m 33s
# 17000:	learn: 0.9161038	test: 0.9036526	best: 0.9036526 (17000)	total: 2m 33s	remaining: 12m 28s
# 17500:	learn: 0.9166688	test: 0.9040492	best: 0.9040511 (17496)	total: 2m 37s	remaining: 12m 23s
# 18000:	learn: 0.9171579	test: 0.9043980	best: 0.9043980 (18000)	total: 2m 41s	remaining: 12m 17s
# 18500:	learn: 0.9176910	test: 0.9047713	best: 0.9047713 (18500)	total: 2m 46s	remaining: 12m 13s
# 19000:	learn: 0.9181816	test: 0.9051526	best: 0.9051557 (18994)	total: 2m 50s	remaining: 12m 7s
# 19500:	learn: 0.9186240	test: 0.9054191	best: 0.9054195 (19487)	total: 2m 55s	remaining: 12m 2s
# 20000:	learn: 0.9190468	test: 0.9056829	best: 0.9056829 (20000)	total: 2m 59s	remaining: 11m 58s
# 20500:	learn: 0.9194900	test: 0.9059415	best: 0.9059423 (20496)	total: 3m 4s	remaining: 11m 54s
# 21000:	learn: 0.9199305	test: 0.9061971	best: 0.9061972 (20999)	total: 3m 8s	remaining: 11m 50s
# 21500:	learn: 0.9203283	test: 0.9064248	best: 0.9064262 (21490)	total: 3m 13s	remaining: 11m 46s
# 22000:	learn: 0.9207621	test: 0.9067288	best: 0.9067326 (21988)	total: 3m 17s	remaining: 11m 41s
# 22500:	learn: 0.9211630	test: 0.9069585	best: 0.9069585 (22500)	total: 3m 22s	remaining: 11m 36s
# 23000:	learn: 0.9215279	test: 0.9071972	best: 0.9071974 (22998)	total: 3m 26s	remaining: 11m 32s
# 23500:	learn: 0.9218802	test: 0.9073797	best: 0.9073806 (23497)	total: 3m 31s	remaining: 11m 26s
# 24000:	learn: 0.9222384	test: 0.9075634	best: 0.9075646 (23997)	total: 3m 35s	remaining: 11m 21s
# 24500:	learn: 0.9226063	test: 0.9078012	best: 0.9078032 (24494)	total: 3m 39s	remaining: 11m 15s
# 25000:	learn: 0.9229115	test: 0.9080104	best: 0.9080117 (24994)	total: 3m 43s	remaining: 11m 10s
# 25500:	learn: 0.9232426	test: 0.9082065	best: 0.9082085 (25499)	total: 3m 47s	remaining: 11m 5s
# 26000:	learn: 0.9235553	test: 0.9084080	best: 0.9084080 (26000)	total: 3m 52s	remaining: 11m
# 26500:	learn: 0.9238556	test: 0.9085556	best: 0.9085588 (26479)	total: 3m 56s	remaining: 10m 56s
# 27000:	learn: 0.9241744	test: 0.9087039	best: 0.9087049 (26984)	total: 4m	remaining: 10m 50s
# 27500:	learn: 0.9244710	test: 0.9088463	best: 0.9088463 (27500)	total: 4m 5s	remaining: 10m 46s
# 28000:	learn: 0.9247621	test: 0.9089749	best: 0.9089764 (27985)	total: 4m 9s	remaining: 10m 41s
# 28500:	learn: 0.9250492	test: 0.9091149	best: 0.9091149 (28500)	total: 4m 13s	remaining: 10m 36s
# 29000:	learn: 0.9253301	test: 0.9092194	best: 0.9092200 (28996)	total: 4m 18s	remaining: 10m 31s
# 29500:	learn: 0.9256184	test: 0.9093773	best: 0.9093773 (29499)	total: 4m 22s	remaining: 10m 26s
# 30000:	learn: 0.9258990	test: 0.9094966	best: 0.9094966 (29956)	total: 4m 26s	remaining: 10m 21s
# 30500:	learn: 0.9261603	test: 0.9095973	best: 0.9095973 (30500)	total: 4m 30s	remaining: 10m 17s
# 31000:	learn: 0.9264302	test: 0.9096822	best: 0.9096822 (31000)	total: 4m 35s	remaining: 10m 12s
# 31500:	learn: 0.9266849	test: 0.9097944	best: 0.9097967 (31494)	total: 4m 39s	remaining: 10m 7s
# 32000:	learn: 0.9269453	test: 0.9099092	best: 0.9099092 (31995)	total: 4m 44s	remaining: 10m 3s
# 32500:	learn: 0.9272146	test: 0.9100273	best: 0.9100273 (32500)	total: 4m 48s	remaining: 9m 59s
# 33000:	learn: 0.9274853	test: 0.9101370	best: 0.9101370 (33000)	total: 4m 53s	remaining: 9m 55s
# 33500:	learn: 0.9277282	test: 0.9102252	best: 0.9102252 (33500)	total: 4m 57s	remaining: 9m 51s
# 34000:	learn: 0.9279674	test: 0.9103000	best: 0.9103006 (33980)	total: 5m 2s	remaining: 9m 47s
# 34500:	learn: 0.9282137	test: 0.9103903	best: 0.9103906 (34443)	total: 5m 7s	remaining: 9m 43s
# 35000:	learn: 0.9284506	test: 0.9104701	best: 0.9104707 (34998)	total: 5m 11s	remaining: 9m 38s
# 35500:	learn: 0.9286851	test: 0.9105458	best: 0.9105476 (35499)	total: 5m 16s	remaining: 9m 35s
# 36000:	learn: 0.9289101	test: 0.9106000	best: 0.9106012 (35995)	total: 5m 20s	remaining: 9m 30s
# 36500:	learn: 0.9291523	test: 0.9106482	best: 0.9106540 (36468)	total: 5m 25s	remaining: 9m 25s
# 37000:	learn: 0.9293887	test: 0.9107113	best: 0.9107120 (36999)	total: 5m 29s	remaining: 9m 21s
# 37500:	learn: 0.9296061	test: 0.9107783	best: 0.9107797 (37495)	total: 5m 34s	remaining: 9m 17s
# 38000:	learn: 0.9298265	test: 0.9108249	best: 0.9108264 (37972)	total: 5m 38s	remaining: 9m 12s
# 38500:	learn: 0.9300590	test: 0.9108830	best: 0.9108831 (38497)	total: 5m 43s	remaining: 9m 8s
# 39000:	learn: 0.9302806	test: 0.9109411	best: 0.9109421 (38997)	total: 5m 47s	remaining: 9m 4s
# 39500:	learn: 0.9305009	test: 0.9110186	best: 0.9110186 (39500)	total: 5m 52s	remaining: 8m 59s
# 40000:	learn: 0.9307141	test: 0.9110736	best: 0.9110759 (39992)	total: 5m 57s	remaining: 8m 55s
# 40500:	learn: 0.9309193	test: 0.9111019	best: 0.9111055 (40492)	total: 6m 1s	remaining: 8m 51s
# 41000:	learn: 0.9311454	test: 0.9111587	best: 0.9111591 (40999)	total: 6m 6s	remaining: 8m 47s
# 41500:	learn: 0.9313674	test: 0.9112186	best: 0.9112186 (41500)	total: 6m 11s	remaining: 8m 43s
# 42000:	learn: 0.9315733	test: 0.9112534	best: 0.9112554 (41985)	total: 6m 16s	remaining: 8m 39s
# 42500:	learn: 0.9317954	test: 0.9113134	best: 0.9113169 (42465)	total: 6m 20s	remaining: 8m 35s
# 43000:	learn: 0.9319942	test: 0.9113606	best: 0.9113619 (42990)	total: 6m 25s	remaining: 8m 30s
# 43500:	learn: 0.9322095	test: 0.9113987	best: 0.9113993 (43499)	total: 6m 29s	remaining: 8m 26s
# 44000:	learn: 0.9324108	test: 0.9114499	best: 0.9114537 (43993)	total: 6m 34s	remaining: 8m 21s
# 44500:	learn: 0.9326147	test: 0.9115070	best: 0.9115095 (44476)	total: 6m 38s	remaining: 8m 17s
# 45000:	learn: 0.9328065	test: 0.9115328	best: 0.9115365 (44866)	total: 6m 43s	remaining: 8m 12s
# 45500:	learn: 0.9330083	test: 0.9115414	best: 0.9115475 (45069)	total: 6m 47s	remaining: 8m 8s
# 46000:	learn: 0.9332100	test: 0.9115855	best: 0.9115855 (46000)	total: 6m 51s	remaining: 8m 3s
# 46500:	learn: 0.9334177	test: 0.9116102	best: 0.9116139 (46476)	total: 6m 56s	remaining: 7m 58s
# 47000:	learn: 0.9336116	test: 0.9116286	best: 0.9116286 (47000)	total: 7m	remaining: 7m 53s
# 47500:	learn: 0.9337929	test: 0.9116489	best: 0.9116556 (47449)	total: 7m 4s	remaining: 7m 48s
# 48000:	learn: 0.9339916	test: 0.9117016	best: 0.9117072 (47984)	total: 7m 8s	remaining: 7m 44s
# 48500:	learn: 0.9341875	test: 0.9117122	best: 0.9117124 (48498)	total: 7m 13s	remaining: 7m 40s
# 49000:	learn: 0.9343745	test: 0.9117401	best: 0.9117423 (48961)	total: 7m 17s	remaining: 7m 35s
# 49500:	learn: 0.9345743	test: 0.9117781	best: 0.9117823 (49395)	total: 7m 22s	remaining: 7m 30s
# 50000:	learn: 0.9347607	test: 0.9117982	best: 0.9117994 (49811)	total: 7m 26s	remaining: 7m 26s
# 50500:	learn: 0.9349421	test: 0.9118142	best: 0.9118147 (50478)	total: 7m 30s	remaining: 7m 21s
# 51000:	learn: 0.9351363	test: 0.9118255	best: 0.9118337 (50693)	total: 7m 34s	remaining: 7m 16s
# 51500:	learn: 0.9353305	test: 0.9118423	best: 0.9118425 (51433)	total: 7m 38s	remaining: 7m 11s
# 52000:	learn: 0.9355092	test: 0.9118848	best: 0.9118886 (51975)	total: 7m 42s	remaining: 7m 7s
# 52500:	learn: 0.9356902	test: 0.9119089	best: 0.9119089 (52500)	total: 7m 47s	remaining: 7m 2s
# 53000:	learn: 0.9358761	test: 0.9119277	best: 0.9119302 (52980)	total: 7m 51s	remaining: 6m 58s
# 53500:	learn: 0.9360655	test: 0.9119463	best: 0.9119485 (53294)	total: 7m 56s	remaining: 6m 53s
# 54000:	learn: 0.9362413	test: 0.9119707	best: 0.9119719 (53994)	total: 8m	remaining: 6m 49s
# 54500:	learn: 0.9364191	test: 0.9119846	best: 0.9119881 (54138)	total: 8m 5s	remaining: 6m 45s
# 55000:	learn: 0.9365991	test: 0.9120090	best: 0.9120096 (54982)	total: 8m 10s	remaining: 6m 41s
# 55500:	learn: 0.9367797	test: 0.9120390	best: 0.9120401 (55435)	total: 8m 15s	remaining: 6m 36s
# 56000:	learn: 0.9369542	test: 0.9120667	best: 0.9120684 (55964)	total: 8m 19s	remaining: 6m 32s
# 56500:	learn: 0.9371279	test: 0.9120737	best: 0.9120787 (56493)	total: 8m 23s	remaining: 6m 27s
# 57000:	learn: 0.9373186	test: 0.9120945	best: 0.9120982 (56946)	total: 8m 28s	remaining: 6m 23s
# 57500:	learn: 0.9375051	test: 0.9121025	best: 0.9121078 (57258)	total: 8m 32s	remaining: 6m 19s
# 58000:	learn: 0.9376730	test: 0.9120950	best: 0.9121105 (57636)	total: 8m 37s	remaining: 6m 14s
# 58500:	learn: 0.9378591	test: 0.9121071	best: 0.9121120 (58182)	total: 8m 42s	remaining: 6m 10s
# 59000:	learn: 0.9380394	test: 0.9121245	best: 0.9121255 (58990)	total: 8m 46s	remaining: 6m 5s
# 59500:	learn: 0.9382066	test: 0.9121620	best: 0.9121624 (59493)	total: 8m 50s	remaining: 6m 1s
# 60000:	learn: 0.9383832	test: 0.9121854	best: 0.9121906 (59948)	total: 8m 55s	remaining: 5m 56s
# 60500:	learn: 0.9385577	test: 0.9121748	best: 0.9121934 (60102)	total: 8m 59s	remaining: 5m 52s
# 61000:	learn: 0.9387352	test: 0.9122227	best: 0.9122232 (60999)	total: 9m 4s	remaining: 5m 47s
# 61500:	learn: 0.9389155	test: 0.9122633	best: 0.9122633 (61500)	total: 9m 8s	remaining: 5m 43s
# 62000:	learn: 0.9390917	test: 0.9122714	best: 0.9122770 (61909)	total: 9m 13s	remaining: 5m 39s
# 62500:	learn: 0.9392576	test: 0.9122764	best: 0.9122770 (61909)	total: 9m 17s	remaining: 5m 34s
# 63000:	learn: 0.9394220	test: 0.9122869	best: 0.9122939 (62974)	total: 9m 22s	remaining: 5m 30s
# 63500:	learn: 0.9395871	test: 0.9122885	best: 0.9122943 (63207)	total: 9m 26s	remaining: 5m 25s
# 64000:	learn: 0.9397572	test: 0.9123040	best: 0.9123042 (63999)	total: 9m 30s	remaining: 5m 20s
# 64500:	learn: 0.9399328	test: 0.9123059	best: 0.9123140 (64078)	total: 9m 34s	remaining: 5m 16s
# 65000:	learn: 0.9401035	test: 0.9123412	best: 0.9123430 (64995)	total: 9m 38s	remaining: 5m 11s
# 65500:	learn: 0.9402784	test: 0.9123761	best: 0.9123808 (65439)	total: 9m 43s	remaining: 5m 7s
# 66000:	learn: 0.9404500	test: 0.9123732	best: 0.9123808 (65439)	total: 9m 48s	remaining: 5m 2s
# 66500:	learn: 0.9406158	test: 0.9123975	best: 0.9123988 (66491)	total: 9m 52s	remaining: 4m 58s
# 67000:	learn: 0.9407871	test: 0.9124180	best: 0.9124180 (67000)	total: 9m 56s	remaining: 4m 53s
# 67500:	learn: 0.9409434	test: 0.9124177	best: 0.9124250 (67201)	total: 10m 1s	remaining: 4m 49s
# 68000:	learn: 0.9411093	test: 0.9124245	best: 0.9124306 (67959)	total: 10m 5s	remaining: 4m 44s
# 68500:	learn: 0.9412696	test: 0.9124370	best: 0.9124420 (68428)	total: 10m 9s	remaining: 4m 40s
# 69000:	learn: 0.9414261	test: 0.9124346	best: 0.9124509 (68577)	total: 10m 14s	remaining: 4m 36s
# 69500:	learn: 0.9415950	test: 0.9124327	best: 0.9124509 (68577)	total: 10m 19s	remaining: 4m 31s
# bestTest = 0.91245085
# bestIteration = 68577
# Shrink model to first 68578 iterations.
# Fold 3
# 0:	learn: 0.5241289	test: 0.5305157	best: 0.5305157 (0)	total: 10.9ms	remaining: 18m 13s
# 500:	learn: 0.7765419	test: 0.7706706	best: 0.7706706 (500)	total: 4.6s	remaining: 15m 14s
# 1000:	learn: 0.8104487	test: 0.8047810	best: 0.8047850 (999)	total: 9.16s	remaining: 15m 5s
# 1500:	learn: 0.8309463	test: 0.8254116	best: 0.8254116 (1500)	total: 13.8s	remaining: 15m 6s
# 2000:	learn: 0.8453836	test: 0.8393572	best: 0.8393572 (2000)	total: 18s	remaining: 14m 39s
# 2500:	learn: 0.8556275	test: 0.8487931	best: 0.8487931 (2500)	total: 22.3s	remaining: 14m 30s
# 3000:	learn: 0.8639975	test: 0.8566512	best: 0.8566512 (3000)	total: 26.7s	remaining: 14m 22s
# 3500:	learn: 0.8702892	test: 0.8621204	best: 0.8621204 (3500)	total: 30.7s	remaining: 14m 7s
# 4000:	learn: 0.8755495	test: 0.8670403	best: 0.8670403 (4000)	total: 35.1s	remaining: 14m 2s
# 4500:	learn: 0.8799047	test: 0.8709743	best: 0.8709743 (4500)	total: 39.3s	remaining: 13m 54s
# 5000:	learn: 0.8836685	test: 0.8744486	best: 0.8744486 (5000)	total: 43.9s	remaining: 13m 54s
# 5500:	learn: 0.8869607	test: 0.8775228	best: 0.8775228 (5500)	total: 48.5s	remaining: 13m 52s
# 6000:	learn: 0.8899116	test: 0.8801317	best: 0.8801317 (6000)	total: 52.9s	remaining: 13m 49s
# 6500:	learn: 0.8924236	test: 0.8824299	best: 0.8824299 (6500)	total: 57.2s	remaining: 13m 43s
# 7000:	learn: 0.8946942	test: 0.8845494	best: 0.8845494 (7000)	total: 1m 1s	remaining: 13m 38s
# 7500:	learn: 0.8966626	test: 0.8864118	best: 0.8864140 (7499)	total: 1m 5s	remaining: 13m 31s
# 8000:	learn: 0.8984644	test: 0.8880585	best: 0.8880585 (8000)	total: 1m 9s	remaining: 13m 24s
# 8500:	learn: 0.9001418	test: 0.8895846	best: 0.8895851 (8497)	total: 1m 14s	remaining: 13m 19s
# 9000:	learn: 0.9016700	test: 0.8909250	best: 0.8909250 (9000)	total: 1m 18s	remaining: 13m 11s
# 9500:	learn: 0.9031168	test: 0.8922791	best: 0.8922805 (9499)	total: 1m 22s	remaining: 13m 7s
# 10000:	learn: 0.9044145	test: 0.8934843	best: 0.8934843 (10000)	total: 1m 27s	remaining: 13m 4s
# 10500:	learn: 0.9056785	test: 0.8945775	best: 0.8945775 (10500)	total: 1m 31s	remaining: 13m 2s
# 11000:	learn: 0.9067707	test: 0.8955733	best: 0.8955733 (11000)	total: 1m 36s	remaining: 13m
# 11500:	learn: 0.9078069	test: 0.8964416	best: 0.8964416 (11500)	total: 1m 41s	remaining: 12m 57s
# 12000:	learn: 0.9087364	test: 0.8972607	best: 0.8972618 (11999)	total: 1m 45s	remaining: 12m 54s
# 12500:	learn: 0.9096447	test: 0.8981441	best: 0.8981448 (12499)	total: 1m 50s	remaining: 12m 51s
# 13000:	learn: 0.9105053	test: 0.8989151	best: 0.8989159 (12999)	total: 1m 54s	remaining: 12m 48s
# 13500:	learn: 0.9113735	test: 0.8997059	best: 0.8997059 (13500)	total: 1m 59s	remaining: 12m 44s
# 14000:	learn: 0.9121865	test: 0.9004017	best: 0.9004030 (13999)	total: 2m 4s	remaining: 12m 41s
# 14500:	learn: 0.9128956	test: 0.9009842	best: 0.9009846 (14498)	total: 2m 8s	remaining: 12m 38s
# 15000:	learn: 0.9136289	test: 0.9015367	best: 0.9015367 (15000)	total: 2m 13s	remaining: 12m 34s
# 15500:	learn: 0.9143259	test: 0.9021260	best: 0.9021277 (15498)	total: 2m 17s	remaining: 12m 29s
# 16000:	learn: 0.9149681	test: 0.9026320	best: 0.9026320 (16000)	total: 2m 22s	remaining: 12m 26s
# 16500:	learn: 0.9155731	test: 0.9031299	best: 0.9031299 (16500)	total: 2m 26s	remaining: 12m 21s
# 17000:	learn: 0.9161409	test: 0.9036169	best: 0.9036169 (17000)	total: 2m 31s	remaining: 12m 17s
# 17500:	learn: 0.9166816	test: 0.9040335	best: 0.9040335 (17500)	total: 2m 35s	remaining: 12m 13s
# 18000:	learn: 0.9171939	test: 0.9044749	best: 0.9044757 (17999)	total: 2m 39s	remaining: 12m 7s
# 18500:	learn: 0.9176989	test: 0.9048637	best: 0.9048637 (18500)	total: 2m 43s	remaining: 12m 1s
# 19000:	learn: 0.9181828	test: 0.9052601	best: 0.9052617 (18997)	total: 2m 47s	remaining: 11m 56s
# 19500:	learn: 0.9186195	test: 0.9055298	best: 0.9055317 (19497)	total: 2m 52s	remaining: 11m 50s
# 20000:	learn: 0.9190654	test: 0.9058642	best: 0.9058642 (20000)	total: 2m 56s	remaining: 11m 46s
# 20500:	learn: 0.9195013	test: 0.9061715	best: 0.9061715 (20500)	total: 3m 1s	remaining: 11m 42s
# 21000:	learn: 0.9199113	test: 0.9064289	best: 0.9064289 (21000)	total: 3m 5s	remaining: 11m 37s
# 21500:	learn: 0.9203111	test: 0.9067209	best: 0.9067209 (21500)	total: 3m 9s	remaining: 11m 33s
# 22000:	learn: 0.9207096	test: 0.9070167	best: 0.9070181 (21999)	total: 3m 14s	remaining: 11m 29s
# 22500:	learn: 0.9210910	test: 0.9072935	best: 0.9072935 (22500)	total: 3m 19s	remaining: 11m 26s
# 23000:	learn: 0.9214743	test: 0.9075217	best: 0.9075221 (22999)	total: 3m 24s	remaining: 11m 23s
# 23500:	learn: 0.9218569	test: 0.9077026	best: 0.9077036 (23491)	total: 3m 28s	remaining: 11m 19s
# 24000:	learn: 0.9222034	test: 0.9079012	best: 0.9079012 (24000)	total: 3m 33s	remaining: 11m 15s
# 24500:	learn: 0.9225544	test: 0.9081150	best: 0.9081189 (24493)	total: 3m 38s	remaining: 11m 11s
# 25000:	learn: 0.9228663	test: 0.9082918	best: 0.9082946 (24994)	total: 3m 42s	remaining: 11m 7s
# 25500:	learn: 0.9232052	test: 0.9085173	best: 0.9085178 (25498)	total: 3m 46s	remaining: 11m 3s
# 26000:	learn: 0.9235400	test: 0.9087594	best: 0.9087600 (25998)	total: 3m 51s	remaining: 10m 58s
# 26500:	learn: 0.9238516	test: 0.9089751	best: 0.9089763 (26497)	total: 3m 55s	remaining: 10m 54s
# 27000:	learn: 0.9241546	test: 0.9091545	best: 0.9091545 (27000)	total: 4m	remaining: 10m 50s
# 27500:	learn: 0.9244206	test: 0.9093257	best: 0.9093261 (27499)	total: 4m 4s	remaining: 10m 45s
# 28000:	learn: 0.9247078	test: 0.9094933	best: 0.9094933 (28000)	total: 4m 9s	remaining: 10m 40s
# 28500:	learn: 0.9250073	test: 0.9096121	best: 0.9096121 (28500)	total: 4m 13s	remaining: 10m 35s
# 29000:	learn: 0.9252895	test: 0.9097430	best: 0.9097432 (28999)	total: 4m 17s	remaining: 10m 30s
# 29500:	learn: 0.9255690	test: 0.9098550	best: 0.9098559 (29497)	total: 4m 22s	remaining: 10m 26s
# 30000:	learn: 0.9258456	test: 0.9099438	best: 0.9099446 (29996)	total: 4m 26s	remaining: 10m 22s
# 30500:	learn: 0.9261290	test: 0.9100776	best: 0.9100783 (30496)	total: 4m 30s	remaining: 10m 17s
# 31000:	learn: 0.9263799	test: 0.9102063	best: 0.9102081 (30996)	total: 4m 35s	remaining: 10m 12s
# 31500:	learn: 0.9266480	test: 0.9103478	best: 0.9103487 (31497)	total: 4m 39s	remaining: 10m 7s
# 32000:	learn: 0.9269025	test: 0.9104864	best: 0.9104864 (32000)	total: 4m 43s	remaining: 10m 2s
# 32500:	learn: 0.9271508	test: 0.9106140	best: 0.9106154 (32484)	total: 4m 47s	remaining: 9m 57s
# 33000:	learn: 0.9274127	test: 0.9107421	best: 0.9107438 (32998)	total: 4m 52s	remaining: 9m 53s
# 33500:	learn: 0.9276613	test: 0.9108325	best: 0.9108341 (33494)	total: 4m 56s	remaining: 9m 48s
# 34000:	learn: 0.9278960	test: 0.9109114	best: 0.9109133 (33979)	total: 5m	remaining: 9m 43s
# 34500:	learn: 0.9281312	test: 0.9109816	best: 0.9109828 (34444)	total: 5m 4s	remaining: 9m 38s
# 35000:	learn: 0.9283621	test: 0.9110650	best: 0.9110700 (34957)	total: 5m 8s	remaining: 9m 33s
# 35500:	learn: 0.9286005	test: 0.9111472	best: 0.9111472 (35500)	total: 5m 13s	remaining: 9m 29s
# 36000:	learn: 0.9288384	test: 0.9112669	best: 0.9112669 (36000)	total: 5m 18s	remaining: 9m 25s
# 36500:	learn: 0.9290713	test: 0.9113624	best: 0.9113656 (36491)	total: 5m 23s	remaining: 9m 22s
# 37000:	learn: 0.9293095	test: 0.9114490	best: 0.9114490 (37000)	total: 5m 27s	remaining: 9m 17s
# 37500:	learn: 0.9295468	test: 0.9115087	best: 0.9115123 (37482)	total: 5m 32s	remaining: 9m 13s
# 38000:	learn: 0.9297772	test: 0.9115622	best: 0.9115641 (37981)	total: 5m 36s	remaining: 9m 9s
# 38500:	learn: 0.9299971	test: 0.9116411	best: 0.9116411 (38500)	total: 5m 41s	remaining: 9m 4s
# 39000:	learn: 0.9302198	test: 0.9117143	best: 0.9117148 (38996)	total: 5m 45s	remaining: 9m
# 39500:	learn: 0.9304355	test: 0.9117700	best: 0.9117754 (39469)	total: 5m 50s	remaining: 8m 56s
# 40000:	learn: 0.9306653	test: 0.9118659	best: 0.9118677 (39999)	total: 5m 55s	remaining: 8m 52s
# 40500:	learn: 0.9308833	test: 0.9119512	best: 0.9119512 (40500)	total: 5m 59s	remaining: 8m 48s
# 41000:	learn: 0.9310992	test: 0.9120328	best: 0.9120328 (41000)	total: 6m 4s	remaining: 8m 44s
# 41500:	learn: 0.9313074	test: 0.9121080	best: 0.9121091 (41497)	total: 6m 8s	remaining: 8m 40s
# 42000:	learn: 0.9315256	test: 0.9121674	best: 0.9121674 (42000)	total: 6m 13s	remaining: 8m 35s
# 42500:	learn: 0.9317291	test: 0.9122224	best: 0.9122276 (42388)	total: 6m 18s	remaining: 8m 31s
# 43000:	learn: 0.9319416	test: 0.9122605	best: 0.9122618 (42996)	total: 6m 22s	remaining: 8m 27s
# 43500:	learn: 0.9321527	test: 0.9123185	best: 0.9123231 (43488)	total: 6m 27s	remaining: 8m 23s
# 44000:	learn: 0.9323392	test: 0.9123717	best: 0.9123734 (43987)	total: 6m 31s	remaining: 8m 18s
# 44500:	learn: 0.9325566	test: 0.9124418	best: 0.9124420 (44494)	total: 6m 35s	remaining: 8m 13s
# 45000:	learn: 0.9327626	test: 0.9125035	best: 0.9125049 (44994)	total: 6m 40s	remaining: 8m 8s
# 45500:	learn: 0.9329511	test: 0.9125428	best: 0.9125441 (45497)	total: 6m 44s	remaining: 8m 4s
# 46000:	learn: 0.9331463	test: 0.9125957	best: 0.9125977 (45995)	total: 6m 48s	remaining: 8m
# 46500:	learn: 0.9333330	test: 0.9126182	best: 0.9126202 (46488)	total: 6m 53s	remaining: 7m 55s
# 47000:	learn: 0.9335318	test: 0.9126537	best: 0.9126537 (46926)	total: 6m 57s	remaining: 7m 50s
# 47500:	learn: 0.9337173	test: 0.9126973	best: 0.9126990 (47497)	total: 7m 1s	remaining: 7m 46s
# 48000:	learn: 0.9339133	test: 0.9127612	best: 0.9127624 (47998)	total: 7m 6s	remaining: 7m 42s
# 48500:	learn: 0.9340930	test: 0.9128041	best: 0.9128041 (48500)	total: 7m 10s	remaining: 7m 37s
# 49000:	learn: 0.9342861	test: 0.9128393	best: 0.9128396 (48999)	total: 7m 15s	remaining: 7m 32s
# 49500:	learn: 0.9344727	test: 0.9128764	best: 0.9128767 (49499)	total: 7m 19s	remaining: 7m 28s
# 50000:	learn: 0.9346688	test: 0.9129387	best: 0.9129387 (50000)	total: 7m 23s	remaining: 7m 23s
# 50500:	learn: 0.9348655	test: 0.9129655	best: 0.9129673 (50492)	total: 7m 27s	remaining: 7m 18s
# 51000:	learn: 0.9350560	test: 0.9129863	best: 0.9129935 (50950)	total: 7m 32s	remaining: 7m 14s
# 51500:	learn: 0.9352422	test: 0.9130026	best: 0.9130051 (51395)	total: 7m 36s	remaining: 7m 10s
# 52000:	learn: 0.9354330	test: 0.9130312	best: 0.9130312 (52000)	total: 7m 41s	remaining: 7m 5s
# 52500:	learn: 0.9356071	test: 0.9130593	best: 0.9130669 (52402)	total: 7m 45s	remaining: 7m 1s
# 53000:	learn: 0.9357923	test: 0.9130993	best: 0.9131008 (52873)	total: 7m 49s	remaining: 6m 56s
# 53500:	learn: 0.9359801	test: 0.9131267	best: 0.9131269 (53498)	total: 7m 54s	remaining: 6m 52s
# 54000:	learn: 0.9361559	test: 0.9131253	best: 0.9131283 (53557)	total: 7m 58s	remaining: 6m 48s
# 54500:	learn: 0.9363354	test: 0.9131420	best: 0.9131436 (54478)	total: 8m 3s	remaining: 6m 43s
# 55000:	learn: 0.9365134	test: 0.9131792	best: 0.9131797 (54984)	total: 8m 7s	remaining: 6m 39s
# 55500:	learn: 0.9366970	test: 0.9131971	best: 0.9132020 (55479)	total: 8m 12s	remaining: 6m 34s
# 56000:	learn: 0.9368855	test: 0.9132240	best: 0.9132267 (55881)	total: 8m 16s	remaining: 6m 30s
# 56500:	learn: 0.9370589	test: 0.9132534	best: 0.9132609 (56463)	total: 8m 21s	remaining: 6m 26s
# 57000:	learn: 0.9372459	test: 0.9133049	best: 0.9133092 (56939)	total: 8m 26s	remaining: 6m 21s
# 57500:	learn: 0.9374074	test: 0.9133492	best: 0.9133505 (57499)	total: 8m 30s	remaining: 6m 17s
# 58000:	learn: 0.9375767	test: 0.9133589	best: 0.9133593 (57999)	total: 8m 35s	remaining: 6m 13s
# 58500:	learn: 0.9377544	test: 0.9133591	best: 0.9133806 (58238)	total: 8m 39s	remaining: 6m 8s
# 59000:	learn: 0.9379227	test: 0.9134081	best: 0.9134088 (58999)	total: 8m 44s	remaining: 6m 4s
# 59500:	learn: 0.9381046	test: 0.9134274	best: 0.9134274 (59500)	total: 8m 48s	remaining: 5m 59s
# 60000:	learn: 0.9382820	test: 0.9134799	best: 0.9134821 (59947)	total: 8m 53s	remaining: 5m 55s
# 60500:	learn: 0.9384547	test: 0.9134896	best: 0.9134934 (60484)	total: 8m 57s	remaining: 5m 51s
# 61000:	learn: 0.9386217	test: 0.9135087	best: 0.9135089 (60999)	total: 9m 2s	remaining: 5m 46s
# 61500:	learn: 0.9387887	test: 0.9135163	best: 0.9135166 (61487)	total: 9m 6s	remaining: 5m 42s
# 62000:	learn: 0.9389626	test: 0.9135565	best: 0.9135586 (61992)	total: 9m 10s	remaining: 5m 37s
# 62500:	learn: 0.9391317	test: 0.9135797	best: 0.9135837 (62482)	total: 9m 15s	remaining: 5m 32s
# 63000:	learn: 0.9392939	test: 0.9135861	best: 0.9135882 (62892)	total: 9m 19s	remaining: 5m 28s
# 63500:	learn: 0.9394695	test: 0.9136102	best: 0.9136151 (63359)	total: 9m 23s	remaining: 5m 23s
# 64000:	learn: 0.9396343	test: 0.9136334	best: 0.9136353 (63970)	total: 9m 27s	remaining: 5m 19s
# 64500:	learn: 0.9398029	test: 0.9136571	best: 0.9136571 (64500)	total: 9m 31s	remaining: 5m 14s
# 65000:	learn: 0.9399737	test: 0.9136599	best: 0.9136640 (64786)	total: 9m 35s	remaining: 5m 10s
# 65500:	learn: 0.9401347	test: 0.9136760	best: 0.9136773 (65492)	total: 9m 40s	remaining: 5m 5s
# 66000:	learn: 0.9403019	test: 0.9136967	best: 0.9137002 (65955)	total: 9m 44s	remaining: 5m 1s
# 66500:	learn: 0.9404728	test: 0.9137192	best: 0.9137198 (66492)	total: 9m 49s	remaining: 4m 56s
# 67000:	learn: 0.9406375	test: 0.9137321	best: 0.9137371 (66664)	total: 9m 53s	remaining: 4m 52s
# 67500:	learn: 0.9407990	test: 0.9137353	best: 0.9137395 (67205)	total: 9m 58s	remaining: 4m 48s
# 68000:	learn: 0.9409689	test: 0.9137509	best: 0.9137616 (67933)	total: 10m 2s	remaining: 4m 43s
# 68500:	learn: 0.9411271	test: 0.9137903	best: 0.9137942 (68460)	total: 10m 7s	remaining: 4m 39s
# 69000:	learn: 0.9412990	test: 0.9138119	best: 0.9138123 (68998)	total: 10m 11s	remaining: 4m 34s
# 69500:	learn: 0.9414565	test: 0.9138205	best: 0.9138242 (69458)	total: 10m 16s	remaining: 4m 30s
# 70000:	learn: 0.9416053	test: 0.9138191	best: 0.9138242 (69458)	total: 10m 20s	remaining: 4m 26s
# 70500:	learn: 0.9417812	test: 0.9138443	best: 0.9138457 (70496)	total: 10m 25s	remaining: 4m 21s
# 71000:	learn: 0.9419347	test: 0.9138513	best: 0.9138553 (70937)	total: 10m 29s	remaining: 4m 17s
# 71500:	learn: 0.9420930	test: 0.9138749	best: 0.9138780 (71490)	total: 10m 34s	remaining: 4m 12s
# 72000:	learn: 0.9422476	test: 0.9138857	best: 0.9138910 (71930)	total: 10m 38s	remaining: 4m 8s
# 72500:	learn: 0.9424140	test: 0.9139012	best: 0.9139026 (72448)	total: 10m 43s	remaining: 4m 4s
# 73000:	learn: 0.9425657	test: 0.9138989	best: 0.9139026 (72448)	total: 10m 47s	remaining: 3m 59s
# 73500:	learn: 0.9427209	test: 0.9139005	best: 0.9139051 (73346)	total: 10m 52s	remaining: 3m 55s
# 74000:	learn: 0.9428824	test: 0.9139168	best: 0.9139185 (73966)	total: 10m 56s	remaining: 3m 50s
# 74500:	learn: 0.9430371	test: 0.9139124	best: 0.9139209 (74170)	total: 11m	remaining: 3m 46s
# 75000:	learn: 0.9431883	test: 0.9139240	best: 0.9139329 (74787)	total: 11m 4s	remaining: 3m 41s
# 75500:	learn: 0.9433469	test: 0.9139463	best: 0.9139500 (75477)	total: 11m 9s	remaining: 3m 37s
# 76000:	learn: 0.9435014	test: 0.9139460	best: 0.9139543 (75959)	total: 11m 13s	remaining: 3m 32s
# 76500:	learn: 0.9436561	test: 0.9139591	best: 0.9139614 (76486)	total: 11m 17s	remaining: 3m 28s
# 77000:	learn: 0.9438161	test: 0.9139749	best: 0.9139749 (77000)	total: 11m 21s	remaining: 3m 23s
# 77500:	learn: 0.9439710	test: 0.9139788	best: 0.9139861 (77301)	total: 11m 25s	remaining: 3m 19s
# 78000:	learn: 0.9441235	test: 0.9139763	best: 0.9139881 (77788)	total: 11m 29s	remaining: 3m 14s
# 78500:	learn: 0.9442789	test: 0.9139805	best: 0.9139890 (78433)	total: 11m 34s	remaining: 3m 10s
# 79000:	learn: 0.9444284	test: 0.9139728	best: 0.9139890 (78433)	total: 11m 38s	remaining: 3m 5s
# bestTest = 0.9139890075
# bestIteration = 78433
# Shrink model to first 78434 iterations.
# Fold 4
# 0:	learn: 0.5478875	test: 0.5414455	best: 0.5414455 (0)	total: 11.4ms	remaining: 19m 4s
# 500:	learn: 0.7756123	test: 0.7682374	best: 0.7682374 (500)	total: 4.77s	remaining: 15m 47s
# 1000:	learn: 0.8102261	test: 0.8027923	best: 0.8027930 (998)	total: 9.34s	remaining: 15m 23s
# 1500:	learn: 0.8313082	test: 0.8246288	best: 0.8246288 (1500)	total: 13.9s	remaining: 15m 13s
# 2000:	learn: 0.8454748	test: 0.8391780	best: 0.8391867 (1999)	total: 18.5s	remaining: 15m 7s
# 2500:	learn: 0.8557961	test: 0.8497461	best: 0.8497461 (2500)	total: 23.2s	remaining: 15m 5s
# 3000:	learn: 0.8637436	test: 0.8578239	best: 0.8578239 (3000)	total: 27.9s	remaining: 15m
# 3500:	learn: 0.8702601	test: 0.8643954	best: 0.8643954 (3500)	total: 32.3s	remaining: 14m 49s
# 4000:	learn: 0.8755693	test: 0.8696023	best: 0.8696023 (4000)	total: 36.7s	remaining: 14m 40s
# 4500:	learn: 0.8799213	test: 0.8739955	best: 0.8740017 (4498)	total: 40.9s	remaining: 14m 28s
# 5000:	learn: 0.8837571	test: 0.8779126	best: 0.8779126 (5000)	total: 45.5s	remaining: 14m 23s
# 5500:	learn: 0.8871366	test: 0.8812050	best: 0.8812072 (5499)	total: 49.9s	remaining: 14m 16s
# 6000:	learn: 0.8899178	test: 0.8838295	best: 0.8838295 (6000)	total: 54.3s	remaining: 14m 10s
# 6500:	learn: 0.8925257	test: 0.8862055	best: 0.8862055 (6500)	total: 58.8s	remaining: 14m 5s
# 7000:	learn: 0.8947880	test: 0.8883255	best: 0.8883255 (7000)	total: 1m 3s	remaining: 14m 2s
# 7500:	learn: 0.8969161	test: 0.8903632	best: 0.8903632 (7500)	total: 1m 7s	remaining: 13m 57s
# 8000:	learn: 0.8987924	test: 0.8920032	best: 0.8920032 (8000)	total: 1m 12s	remaining: 13m 50s
# 8500:	learn: 0.9004366	test: 0.8934771	best: 0.8934786 (8498)	total: 1m 16s	remaining: 13m 44s
# 9000:	learn: 0.9019377	test: 0.8947280	best: 0.8947280 (9000)	total: 1m 20s	remaining: 13m 36s
# 9500:	learn: 0.9032948	test: 0.8959940	best: 0.8959948 (9499)	total: 1m 24s	remaining: 13m 28s
# 10000:	learn: 0.9046360	test: 0.8970773	best: 0.8970773 (10000)	total: 1m 29s	remaining: 13m 21s
# 10500:	learn: 0.9057899	test: 0.8980654	best: 0.8980654 (10500)	total: 1m 33s	remaining: 13m 15s
# 11000:	learn: 0.9069111	test: 0.8990101	best: 0.8990123 (10999)	total: 1m 38s	remaining: 13m 13s
# 11500:	learn: 0.9079059	test: 0.8998653	best: 0.8998664 (11497)	total: 1m 42s	remaining: 13m 9s
# 12000:	learn: 0.9087842	test: 0.9006476	best: 0.9006476 (12000)	total: 1m 47s	remaining: 13m 6s
# 12500:	learn: 0.9096944	test: 0.9013956	best: 0.9013956 (12500)	total: 1m 51s	remaining: 13m 1s
# 13000:	learn: 0.9105618	test: 0.9020720	best: 0.9020725 (12996)	total: 1m 55s	remaining: 12m 56s
# 13500:	learn: 0.9113495	test: 0.9026659	best: 0.9026659 (13500)	total: 2m	remaining: 12m 50s
# 14000:	learn: 0.9121332	test: 0.9033130	best: 0.9033174 (13998)	total: 2m 4s	remaining: 12m 45s
# 14500:	learn: 0.9128472	test: 0.9039258	best: 0.9039258 (14500)	total: 2m 8s	remaining: 12m 39s
# 15000:	learn: 0.9135626	test: 0.9044815	best: 0.9044815 (15000)	total: 2m 13s	remaining: 12m 34s
# 15500:	learn: 0.9141930	test: 0.9049926	best: 0.9049926 (15500)	total: 2m 17s	remaining: 12m 31s
# 16000:	learn: 0.9147864	test: 0.9054017	best: 0.9054025 (15994)	total: 2m 22s	remaining: 12m 27s
# 16500:	learn: 0.9153458	test: 0.9057800	best: 0.9057826 (16498)	total: 2m 27s	remaining: 12m 24s
# 17000:	learn: 0.9159119	test: 0.9061877	best: 0.9061877 (17000)	total: 2m 31s	remaining: 12m 20s
# 17500:	learn: 0.9164838	test: 0.9065768	best: 0.9065768 (17500)	total: 2m 36s	remaining: 12m 16s
# 18000:	learn: 0.9170178	test: 0.9069112	best: 0.9069112 (18000)	total: 2m 40s	remaining: 12m 12s
# 18500:	learn: 0.9174903	test: 0.9072291	best: 0.9072344 (18493)	total: 2m 45s	remaining: 12m 8s
# 19000:	learn: 0.9179740	test: 0.9075897	best: 0.9075897 (19000)	total: 2m 49s	remaining: 12m 4s
# 19500:	learn: 0.9184369	test: 0.9078670	best: 0.9078686 (19496)	total: 2m 54s	remaining: 12m
# 20000:	learn: 0.9188761	test: 0.9081206	best: 0.9081206 (20000)	total: 2m 59s	remaining: 11m 56s
# 20500:	learn: 0.9193190	test: 0.9083478	best: 0.9083478 (20500)	total: 3m 3s	remaining: 11m 52s
# 21000:	learn: 0.9197239	test: 0.9085808	best: 0.9085808 (21000)	total: 3m 7s	remaining: 11m 46s
# 21500:	learn: 0.9201258	test: 0.9088061	best: 0.9088067 (21499)	total: 3m 12s	remaining: 11m 41s
# 22000:	learn: 0.9204918	test: 0.9090407	best: 0.9090411 (21999)	total: 3m 16s	remaining: 11m 37s
# 22500:	learn: 0.9208822	test: 0.9093020	best: 0.9093033 (22499)	total: 3m 21s	remaining: 11m 33s
# 23000:	learn: 0.9212406	test: 0.9095076	best: 0.9095094 (22998)	total: 3m 26s	remaining: 11m 29s
# 23500:	learn: 0.9215938	test: 0.9096849	best: 0.9096849 (23500)	total: 3m 30s	remaining: 11m 25s
# 24000:	learn: 0.9219362	test: 0.9098905	best: 0.9098915 (23999)	total: 3m 35s	remaining: 11m 21s
# 24500:	learn: 0.9222807	test: 0.9100785	best: 0.9100798 (24497)	total: 3m 39s	remaining: 11m 16s
# 25000:	learn: 0.9226132	test: 0.9102369	best: 0.9102439 (24984)	total: 3m 44s	remaining: 11m 12s
# 25500:	learn: 0.9229434	test: 0.9103915	best: 0.9103969 (25492)	total: 3m 48s	remaining: 11m 7s
# 26000:	learn: 0.9232535	test: 0.9105737	best: 0.9105737 (26000)	total: 3m 53s	remaining: 11m 3s
# 26500:	learn: 0.9235631	test: 0.9107186	best: 0.9107246 (26495)	total: 3m 57s	remaining: 10m 58s
# 27000:	learn: 0.9238554	test: 0.9108379	best: 0.9108382 (26998)	total: 4m 2s	remaining: 10m 55s
# 27500:	learn: 0.9241462	test: 0.9109756	best: 0.9109756 (27500)	total: 4m 7s	remaining: 10m 51s
# 28000:	learn: 0.9244447	test: 0.9110997	best: 0.9111030 (27988)	total: 4m 11s	remaining: 10m 46s
# 28500:	learn: 0.9247178	test: 0.9112050	best: 0.9112050 (28500)	total: 4m 16s	remaining: 10m 42s
# 29000:	learn: 0.9250130	test: 0.9113204	best: 0.9113204 (28986)	total: 4m 20s	remaining: 10m 38s
# 29500:	learn: 0.9252903	test: 0.9114345	best: 0.9114367 (29499)	total: 4m 25s	remaining: 10m 33s
# 30000:	learn: 0.9255787	test: 0.9115257	best: 0.9115257 (30000)	total: 4m 29s	remaining: 10m 28s
# 30500:	learn: 0.9258366	test: 0.9116132	best: 0.9116155 (30499)	total: 4m 33s	remaining: 10m 23s
# 31000:	learn: 0.9260949	test: 0.9117298	best: 0.9117306 (30995)	total: 4m 38s	remaining: 10m 19s
# 31500:	learn: 0.9263425	test: 0.9117997	best: 0.9118016 (31498)	total: 4m 42s	remaining: 10m 15s
# 32000:	learn: 0.9265996	test: 0.9119012	best: 0.9119021 (31993)	total: 4m 47s	remaining: 10m 10s
# 32500:	learn: 0.9268514	test: 0.9119812	best: 0.9119858 (32490)	total: 4m 52s	remaining: 10m 6s
# 33000:	learn: 0.9270871	test: 0.9120792	best: 0.9120814 (32997)	total: 4m 56s	remaining: 10m 1s
# ...
# 60000:	learn: 0.9384731	test: 0.9106645	best: 0.9106688 (59948)	total: 8m 46s	remaining: 5m 51s
# 60500:	learn: 0.9386458	test: 0.9106947	best: 0.9106960 (60486)	total: 8m 51s	remaining: 5m 46s
# 61000:	learn: 0.9388129	test: 0.9107260	best: 0.9107260 (61000)	total: 8m 55s	remaining: 5m 42s
# 61500:	learn: 0.9389864	test: 0.9107250	best: 0.9107274 (61229)	total: 8m 59s	remaining: 5m 37s
# 62000:	learn: 0.9391472	test: 0.9107373	best: 0.9107444 (61900)	total: 9m 4s	remaining: 5m 33s
# 62500:	learn: 0.9393137	test: 0.9107777	best: 0.9107777 (62500)	total: 9m 8s	remaining: 5m 28s
# 63000:	learn: 0.9394776	test: 0.9108011	best: 0.9108011 (63000)	total: 9m 12s	remaining: 5m 24s
# 63500:	learn: 0.9396495	test: 0.9108294	best: 0.9108328 (63490)	total: 9m 16s	remaining: 5m 19s
# 64000:	learn: 0.9398160	test: 0.9108595	best: 0.9108596 (63999)	total: 9m 21s	remaining: 5m 15s
# 64500:	learn: 0.9399846	test: 0.9108898	best: 0.9108921 (64496)	total: 9m 25s	remaining: 5m 11s
# 65000:	learn: 0.9401493	test: 0.9109160	best: 0.9109163 (64997)	total: 9m 29s	remaining: 5m 6s
# 65500:	learn: 0.9403113	test: 0.9109377	best: 0.9109377 (65500)	total: 9m 34s	remaining: 5m 2s
# 66000:	learn: 0.9404790	test: 0.9109574	best: 0.9109604 (65816)	total: 9m 39s	remaining: 4m 58s
# 66500:	learn: 0.9406435	test: 0.9109831	best: 0.9109862 (66448)	total: 9m 43s	remaining: 4m 54s
# 67000:	learn: 0.9408132	test: 0.9109999	best: 0.9110027 (66700)	total: 9m 48s	remaining: 4m 49s
# 67500:	learn: 0.9409770	test: 0.9110170	best: 0.9110194 (67474)	total: 9m 53s	remaining: 4m 45s
# 68000:	learn: 0.9411304	test: 0.9110334	best: 0.9110338 (67995)	total: 9m 57s	remaining: 4m 41s
# 68500:	learn: 0.9412948	test: 0.9110563	best: 0.9110569 (68453)	total: 10m 1s	remaining: 4m 36s
# 69000:	learn: 0.9414584	test: 0.9110844	best: 0.9110901 (68969)	total: 10m 6s	remaining: 4m 32s
# 69500:	learn: 0.9416103	test: 0.9111045	best: 0.9111063 (69479)	total: 10m 10s	remaining: 4m 28s
# 70000:	learn: 0.9417715	test: 0.9111274	best: 0.9111274 (70000)	total: 10m 15s	remaining: 4m 23s
# 70500:	learn: 0.9419390	test: 0.9111522	best: 0.9111534 (70489)	total: 10m 19s	remaining: 4m 19s
# 71000:	learn: 0.9420961	test: 0.9111858	best: 0.9111858 (71000)	total: 10m 24s	remaining: 4m 15s
# 71500:	learn: 0.9422544	test: 0.9112144	best: 0.9112172 (71486)	total: 10m 29s	remaining: 4m 10s
# 72000:	learn: 0.9424085	test: 0.9112193	best: 0.9112220 (71977)	total: 10m 33s	remaining: 4m 6s
# 72500:	learn: 0.9425607	test: 0.9112468	best: 0.9112478 (72499)	total: 10m 37s	remaining: 4m 1s
# 73000:	learn: 0.9427232	test: 0.9112460	best: 0.9112530 (72611)	total: 10m 42s	remaining: 3m 57s
# 73500:	learn: 0.9428750	test: 0.9112372	best: 0.9112530 (72611)	total: 10m 46s	remaining: 3m 53s
# bestTest = 0.9112530351
# bestIteration = 72611
# Shrink model to first 72612 iterations.
# Fold 7
# 0:	learn: 0.5299202	test: 0.5308987	best: 0.5308987 (0)	total: 10.3ms	remaining: 17m 8s
# 500:	learn: 0.7777428	test: 0.7767312	best: 0.7767312 (500)	total: 4.56s	remaining: 15m 5s
# 1000:	learn: 0.8107304	test: 0.8090250	best: 0.8090250 (1000)	total: 9.34s	remaining: 15m 23s
# 1500:	learn: 0.8314683	test: 0.8286789	best: 0.8286789 (1500)	total: 13.6s	remaining: 14m 51s
# 2000:	learn: 0.8451203	test: 0.8418860	best: 0.8418860 (2000)	total: 18.2s	remaining: 14m 51s
# 2500:	learn: 0.8554647	test: 0.8522311	best: 0.8522311 (2500)	total: 22.6s	remaining: 14m 42s
# 3000:	learn: 0.8635888	test: 0.8603331	best: 0.8603331 (3000)	total: 27.1s	remaining: 14m 36s
# 3500:	learn: 0.8698935	test: 0.8664526	best: 0.8664526 (3500)	total: 31.5s	remaining: 14m 27s
# 4000:	learn: 0.8752636	test: 0.8717905	best: 0.8717905 (4000)	total: 35.6s	remaining: 14m 14s
# 4500:	learn: 0.8795775	test: 0.8758995	best: 0.8759017 (4499)	total: 39.9s	remaining: 14m 5s
# 5000:	learn: 0.8832222	test: 0.8793233	best: 0.8793233 (5000)	total: 44s	remaining: 13m 56s
# 5500:	learn: 0.8867257	test: 0.8824248	best: 0.8824248 (5500)	total: 48.3s	remaining: 13m 50s
# 6000:	learn: 0.8895073	test: 0.8849555	best: 0.8849555 (6000)	total: 52.6s	remaining: 13m 43s
# 6500:	learn: 0.8920212	test: 0.8871564	best: 0.8871564 (6500)	total: 57s	remaining: 13m 39s
# 7000:	learn: 0.8943399	test: 0.8893042	best: 0.8893042 (7000)	total: 1m 1s	remaining: 13m 35s
# 7500:	learn: 0.8963049	test: 0.8911088	best: 0.8911088 (7500)	total: 1m 5s	remaining: 13m 28s
# 8000:	learn: 0.8981357	test: 0.8927351	best: 0.8927351 (8000)	total: 1m 9s	remaining: 13m 22s
# 8500:	learn: 0.8997887	test: 0.8941961	best: 0.8941961 (8500)	total: 1m 14s	remaining: 13m 16s
# 9000:	learn: 0.9013528	test: 0.8954836	best: 0.8954836 (9000)	total: 1m 18s	remaining: 13m 13s
# 9500:	learn: 0.9027097	test: 0.8965954	best: 0.8965954 (9500)	total: 1m 22s	remaining: 13m 6s
# 10000:	learn: 0.9039322	test: 0.8976871	best: 0.8976871 (10000)	total: 1m 26s	remaining: 13m
# 10500:	learn: 0.9051638	test: 0.8987592	best: 0.8987592 (10500)	total: 1m 30s	remaining: 12m 54s
# 11000:	learn: 0.9063307	test: 0.8996947	best: 0.8996947 (11000)	total: 1m 35s	remaining: 12m 49s
# 11500:	learn: 0.9073495	test: 0.9005738	best: 0.9005739 (11499)	total: 1m 39s	remaining: 12m 46s
# 12000:	learn: 0.9083084	test: 0.9013024	best: 0.9013024 (12000)	total: 1m 44s	remaining: 12m 43s
# 12500:	learn: 0.9092695	test: 0.9020239	best: 0.9020253 (12499)	total: 1m 48s	remaining: 12m 39s
# 13000:	learn: 0.9101195	test: 0.9026722	best: 0.9026722 (13000)	total: 1m 53s	remaining: 12m 38s
# 13500:	learn: 0.9109169	test: 0.9032798	best: 0.9032815 (13496)	total: 1m 57s	remaining: 12m 35s
# 14000:	learn: 0.9116973	test: 0.9039051	best: 0.9039055 (13999)	total: 2m 2s	remaining: 12m 33s
# 14500:	learn: 0.9124309	test: 0.9044566	best: 0.9044566 (14500)	total: 2m 7s	remaining: 12m 30s
# 15000:	learn: 0.9130946	test: 0.9049370	best: 0.9049413 (14992)	total: 2m 11s	remaining: 12m 26s
# 15500:	learn: 0.9137834	test: 0.9054464	best: 0.9054474 (15499)	total: 2m 16s	remaining: 12m 23s
# 16000:	learn: 0.9144056	test: 0.9059294	best: 0.9059303 (15999)	total: 2m 20s	remaining: 12m 18s
# 16500:	learn: 0.9149934	test: 0.9062886	best: 0.9062914 (16498)	total: 2m 24s	remaining: 12m 12s
# 17000:	learn: 0.9155693	test: 0.9066741	best: 0.9066769 (16981)	total: 2m 29s	remaining: 12m 8s
# 17500:	learn: 0.9161159	test: 0.9070917	best: 0.9070917 (17500)	total: 2m 33s	remaining: 12m 3s
# 18000:	learn: 0.9166453	test: 0.9075102	best: 0.9075106 (17999)	total: 2m 37s	remaining: 11m 59s
# 18500:	learn: 0.9171478	test: 0.9078536	best: 0.9078542 (18499)	total: 2m 42s	remaining: 11m 55s
# 19000:	learn: 0.9176326	test: 0.9081762	best: 0.9081770 (18999)	total: 2m 47s	remaining: 11m 52s
# 19500:	learn: 0.9181234	test: 0.9084762	best: 0.9084764 (19499)	total: 2m 51s	remaining: 11m 49s
# 20000:	learn: 0.9186029	test: 0.9087387	best: 0.9087387 (19994)	total: 2m 56s	remaining: 11m 45s
# 20500:	learn: 0.9190422	test: 0.9090164	best: 0.9090209 (20485)	total: 3m 1s	remaining: 11m 42s
# 21000:	learn: 0.9194740	test: 0.9092673	best: 0.9092673 (21000)	total: 3m 5s	remaining: 11m 38s
# 21500:	learn: 0.9199060	test: 0.9095264	best: 0.9095264 (21500)	total: 3m 10s	remaining: 11m 35s
# 22000:	learn: 0.9203263	test: 0.9097897	best: 0.9097897 (22000)	total: 3m 15s	remaining: 11m 31s
# 22500:	learn: 0.9207140	test: 0.9099950	best: 0.9099950 (22500)	total: 3m 19s	remaining: 11m 28s
# 23000:	learn: 0.9211060	test: 0.9101962	best: 0.9101965 (22999)	total: 3m 24s	remaining: 11m 24s
# 23500:	learn: 0.9214483	test: 0.9103782	best: 0.9103782 (23500)	total: 3m 29s	remaining: 11m 20s
# 24000:	learn: 0.9217934	test: 0.9105345	best: 0.9105345 (24000)	total: 3m 33s	remaining: 11m 16s
# 24500:	learn: 0.9221449	test: 0.9107079	best: 0.9107108 (24497)	total: 3m 38s	remaining: 11m 12s
# 25000:	learn: 0.9224652	test: 0.9108765	best: 0.9108767 (24992)	total: 3m 42s	remaining: 11m 7s
# 25500:	learn: 0.9228142	test: 0.9110700	best: 0.9110700 (25500)	total: 3m 46s	remaining: 11m 2s
# 26000:	learn: 0.9231480	test: 0.9112645	best: 0.9112648 (25997)	total: 3m 51s	remaining: 10m 58s
# 26500:	learn: 0.9234648	test: 0.9114217	best: 0.9114217 (26500)	total: 3m 55s	remaining: 10m 54s
# 27000:	learn: 0.9237802	test: 0.9115509	best: 0.9115509 (26998)	total: 4m	remaining: 10m 50s
# 27500:	learn: 0.9240762	test: 0.9116483	best: 0.9116507 (27495)	total: 4m 5s	remaining: 10m 46s
# 28000:	learn: 0.9243663	test: 0.9117493	best: 0.9117501 (27961)	total: 4m 9s	remaining: 10m 42s
# 28500:	learn: 0.9246330	test: 0.9118322	best: 0.9118322 (28500)	total: 4m 14s	remaining: 10m 37s
# 29000:	learn: 0.9249210	test: 0.9119738	best: 0.9119742 (28999)	total: 4m 19s	remaining: 10m 34s
# 29500:	learn: 0.9251903	test: 0.9120585	best: 0.9120605 (29477)	total: 4m 23s	remaining: 10m 29s
# 30000:	learn: 0.9254662	test: 0.9121882	best: 0.9121906 (29971)	total: 4m 27s	remaining: 10m 25s
# 30500:	learn: 0.9257379	test: 0.9122974	best: 0.9123001 (30496)	total: 4m 32s	remaining: 10m 20s
# 31000:	learn: 0.9259989	test: 0.9124047	best: 0.9124080 (30998)	total: 4m 36s	remaining: 10m 16s
# 31500:	learn: 0.9262569	test: 0.9125059	best: 0.9125069 (31499)	total: 4m 41s	remaining: 10m 12s
# 32000:	learn: 0.9265037	test: 0.9126106	best: 0.9126106 (32000)	total: 4m 46s	remaining: 10m 7s
# 32500:	learn: 0.9267704	test: 0.9126892	best: 0.9126894 (32499)	total: 4m 50s	remaining: 10m 3s
# 33000:	learn: 0.9270350	test: 0.9127827	best: 0.9127867 (32986)	total: 4m 55s	remaining: 9m 59s
# 33500:	learn: 0.9272843	test: 0.9128760	best: 0.9128792 (33488)	total: 4m 59s	remaining: 9m 54s
# 34000:	learn: 0.9275279	test: 0.9129489	best: 0.9129502 (33996)	total: 5m 4s	remaining: 9m 50s
# 34500:	learn: 0.9277773	test: 0.9130186	best: 0.9130196 (34495)	total: 5m 8s	remaining: 9m 46s
# 35000:	learn: 0.9280183	test: 0.9131034	best: 0.9131087 (34934)	total: 5m 13s	remaining: 9m 41s
# 35500:	learn: 0.9282714	test: 0.9131869	best: 0.9131869 (35500)	total: 5m 17s	remaining: 9m 36s
# 36000:	learn: 0.9284994	test: 0.9132403	best: 0.9132439 (35931)	total: 5m 21s	remaining: 9m 31s
# 36500:	learn: 0.9287310	test: 0.9133273	best: 0.9133273 (36500)	total: 5m 25s	remaining: 9m 26s
# 37000:	learn: 0.9289516	test: 0.9133726	best: 0.9133726 (37000)	total: 5m 30s	remaining: 9m 22s
# 37500:	learn: 0.9291801	test: 0.9134457	best: 0.9134464 (37494)	total: 5m 34s	remaining: 9m 17s
# 38000:	learn: 0.9294109	test: 0.9134980	best: 0.9134980 (38000)	total: 5m 39s	remaining: 9m 13s
# 38500:	learn: 0.9296254	test: 0.9135531	best: 0.9135545 (38460)	total: 5m 43s	remaining: 9m 8s
# 39000:	learn: 0.9298409	test: 0.9136059	best: 0.9136066 (38999)	total: 5m 47s	remaining: 9m 3s
# 39500:	learn: 0.9300523	test: 0.9136581	best: 0.9136596 (39496)	total: 5m 51s	remaining: 8m 59s
# 40000:	learn: 0.9302644	test: 0.9137020	best: 0.9137051 (39913)	total: 5m 56s	remaining: 8m 54s
# 40500:	learn: 0.9304819	test: 0.9137329	best: 0.9137342 (40474)	total: 6m	remaining: 8m 49s
# 41000:	learn: 0.9306847	test: 0.9137735	best: 0.9137740 (40996)	total: 6m 4s	remaining: 8m 44s
# 41500:	learn: 0.9308999	test: 0.9138473	best: 0.9138475 (41499)	total: 6m 9s	remaining: 8m 40s
# 42000:	learn: 0.9311148	test: 0.9138790	best: 0.9138796 (41994)	total: 6m 13s	remaining: 8m 36s
# 42500:	learn: 0.9313112	test: 0.9139115	best: 0.9139158 (42485)	total: 6m 18s	remaining: 8m 32s
# 43000:	learn: 0.9315157	test: 0.9139521	best: 0.9139521 (43000)	total: 6m 22s	remaining: 8m 27s
# 43500:	learn: 0.9317215	test: 0.9139740	best: 0.9139754 (43413)	total: 6m 27s	remaining: 8m 23s
# 44000:	learn: 0.9319378	test: 0.9140205	best: 0.9140218 (43983)	total: 6m 32s	remaining: 8m 18s
# 44500:	learn: 0.9321465	test: 0.9140851	best: 0.9140851 (44500)	total: 6m 36s	remaining: 8m 14s
# 45000:	learn: 0.9323477	test: 0.9141317	best: 0.9141317 (45000)	total: 6m 40s	remaining: 8m 9s
# 45500:	learn: 0.9325510	test: 0.9141672	best: 0.9141676 (45499)	total: 6m 45s	remaining: 8m 5s
# 46000:	learn: 0.9327586	test: 0.9142228	best: 0.9142236 (45993)	total: 6m 49s	remaining: 8m
# 46500:	learn: 0.9329641	test: 0.9142696	best: 0.9142710 (46479)	total: 6m 54s	remaining: 7m 56s
# 47000:	learn: 0.9331626	test: 0.9143069	best: 0.9143092 (46924)	total: 6m 58s	remaining: 7m 51s
# 47500:	learn: 0.9333592	test: 0.9143584	best: 0.9143659 (47461)	total: 7m 2s	remaining: 7m 47s
# 48000:	learn: 0.9335541	test: 0.9143912	best: 0.9143943 (47971)	total: 7m 7s	remaining: 7m 43s
# 48500:	learn: 0.9337515	test: 0.9144138	best: 0.9144151 (48489)	total: 7m 12s	remaining: 7m 38s
# 49000:	learn: 0.9339446	test: 0.9144272	best: 0.9144404 (48769)	total: 7m 16s	remaining: 7m 34s
# 49500:	learn: 0.9341273	test: 0.9144559	best: 0.9144577 (49475)	total: 7m 20s	remaining: 7m 29s
# 50000:	learn: 0.9343087	test: 0.9144670	best: 0.9144718 (49771)	total: 7m 24s	remaining: 7m 24s
# 50500:	learn: 0.9345002	test: 0.9144945	best: 0.9144964 (50492)	total: 7m 28s	remaining: 7m 20s
# 51000:	learn: 0.9346914	test: 0.9145451	best: 0.9145468 (50986)	total: 7m 33s	remaining: 7m 15s
# 51500:	learn: 0.9348808	test: 0.9145662	best: 0.9145672 (51483)	total: 7m 37s	remaining: 7m 10s
# 52000:	learn: 0.9350651	test: 0.9145903	best: 0.9145942 (51936)	total: 7m 42s	remaining: 7m 6s
# 52500:	learn: 0.9352491	test: 0.9146109	best: 0.9146119 (52498)	total: 7m 46s	remaining: 7m 1s
# 53000:	learn: 0.9354335	test: 0.9146522	best: 0.9146534 (52978)	total: 7m 50s	remaining: 6m 57s
# 53500:	learn: 0.9356146	test: 0.9146727	best: 0.9146727 (53500)	total: 7m 54s	remaining: 6m 52s
# 54000:	learn: 0.9357858	test: 0.9146967	best: 0.9146991 (53979)	total: 7m 59s	remaining: 6m 48s
# 54500:	learn: 0.9359699	test: 0.9147152	best: 0.9147198 (54477)	total: 8m 4s	remaining: 6m 44s
# 55000:	learn: 0.9361520	test: 0.9147497	best: 0.9147540 (54968)	total: 8m 8s	remaining: 6m 39s
# 55500:	learn: 0.9363295	test: 0.9147903	best: 0.9147903 (55499)	total: 8m 13s	remaining: 6m 35s
# 56000:	learn: 0.9365094	test: 0.9148315	best: 0.9148332 (55993)	total: 8m 18s	remaining: 6m 31s
# 56500:	learn: 0.9366891	test: 0.9148786	best: 0.9148786 (56500)	total: 8m 22s	remaining: 6m 26s
# 57000:	learn: 0.9368724	test: 0.9148982	best: 0.9149070 (56886)	total: 8m 27s	remaining: 6m 22s
# 57500:	learn: 0.9370493	test: 0.9149255	best: 0.9149281 (57484)	total: 8m 31s	remaining: 6m 18s
# 58000:	learn: 0.9372267	test: 0.9149606	best: 0.9149608 (57994)	total: 8m 36s	remaining: 6m 13s
# 58500:	learn: 0.9374064	test: 0.9149832	best: 0.9149840 (58493)	total: 8m 40s	remaining: 6m 9s
# 59000:	learn: 0.9375814	test: 0.9149940	best: 0.9149968 (58921)	total: 8m 44s	remaining: 6m 4s
# 59500:	learn: 0.9377538	test: 0.9150211	best: 0.9150223 (59480)	total: 8m 49s	remaining: 6m
# 60000:	learn: 0.9379299	test: 0.9150507	best: 0.9150552 (59965)	total: 8m 53s	remaining: 5m 55s
# 60500:	learn: 0.9380894	test: 0.9150627	best: 0.9150679 (60402)	total: 8m 58s	remaining: 5m 51s
# 61000:	learn: 0.9382615	test: 0.9150769	best: 0.9150781 (60982)	total: 9m 2s	remaining: 5m 46s
# 61500:	learn: 0.9384373	test: 0.9151061	best: 0.9151061 (61500)	total: 9m 6s	remaining: 5m 42s
# 62000:	learn: 0.9386125	test: 0.9151313	best: 0.9151379 (61925)	total: 9m 11s	remaining: 5m 37s
# 62500:	learn: 0.9387904	test: 0.9151394	best: 0.9151438 (62233)	total: 9m 15s	remaining: 5m 33s
# 63000:	learn: 0.9389550	test: 0.9151564	best: 0.9151573 (62998)	total: 9m 19s	remaining: 5m 28s
# 63500:	learn: 0.9391281	test: 0.9151993	best: 0.9152032 (63357)	total: 9m 24s	remaining: 5m 24s
# 64000:	learn: 0.9392954	test: 0.9151910	best: 0.9152050 (63573)	total: 9m 28s	remaining: 5m 19s
# 64500:	learn: 0.9394696	test: 0.9152182	best: 0.9152194 (64466)	total: 9m 32s	remaining: 5m 15s
# 65000:	learn: 0.9396385	test: 0.9152200	best: 0.9152288 (64651)	total: 9m 36s	remaining: 5m 10s
# 65500:	learn: 0.9398063	test: 0.9152350	best: 0.9152372 (65478)	total: 9m 41s	remaining: 5m 6s
# 66000:	learn: 0.9399732	test: 0.9152451	best: 0.9152487 (65928)	total: 9m 45s	remaining: 5m 1s
# 66500:	learn: 0.9401397	test: 0.9152548	best: 0.9152592 (66389)	total: 9m 49s	remaining: 4m 56s
# 67000:	learn: 0.9403055	test: 0.9152712	best: 0.9152737 (66974)	total: 9m 53s	remaining: 4m 52s
# 67500:	learn: 0.9404720	test: 0.9152865	best: 0.9152921 (67171)	total: 9m 57s	remaining: 4m 47s
# 68000:	learn: 0.9406358	test: 0.9152859	best: 0.9152921 (67171)	total: 10m 1s	remaining: 4m 43s
# bestTest = 0.9152920842
# bestIteration = 67171
# Shrink model to first 67172 iterations.
# CV score: 0.91384

# %%
param = {
    'bagging_freq': 5,
    'bagging_fraction': 0.33,
    'boost_from_average':'false',
    'boost': 'gbdt',
    'feature_fraction': 0.05,
    'learning_rate': 0.01,
    'max_depth': -1,
    'metric':'auc',
    'min_data_in_leaf': 80,
    'min_sum_hessian_in_leaf': 10.0,
    'num_leaves': 13,
    'num_threads': 12,
    'tree_learner': 'serial',
    'objective': 'binary',
    'verbosity': 1
}

# %%
oof = np.zeros(len(train_features))
predictions = np.zeros(len(test))
feature_importance_df = pd.DataFrame()
features = [c for c in train_features.columns if c not in ['ID_code', 'target']]

for i, (train_idx, valid_idx) in enumerate(splits):  
    print(f'Fold {i + 1}')
    x_train = np.array(train_features)
    y_train = np.array(train_target)
    trn_data = lgb.Dataset(x_train[train_idx.astype(int)], label=y_train[train_idx.astype(int)])
    val_data = lgb.Dataset(x_train[valid_idx.astype(int)], label=y_train[valid_idx.astype(int)])
    
    num_round = 100000
    clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=1000, early_stopping_rounds = 3000)
    oof[valid_idx] = clf.predict(x_train[valid_idx], num_iteration=clf.best_iteration)
    
    predictions += clf.predict(test_features, num_iteration=clf.best_iteration) / 5

print("CV score: {:<8.5f}".format(roc_auc_score(train_target, oof)))
# Out:
# Fold 1
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.903128	valid_1's auc: 0.883623
# [2000]	training's auc: 0.914059	valid_1's auc: 0.891729
# [3000]	training's auc: 0.921716	valid_1's auc: 0.896128
# [4000]	training's auc: 0.927681	valid_1's auc: 0.898793
# [5000]	training's auc: 0.932707	valid_1's auc: 0.900501
# [6000]	training's auc: 0.93712	valid_1's auc: 0.901447
# [7000]	training's auc: 0.941245	valid_1's auc: 0.901825
# [8000]	training's auc: 0.945033	valid_1's auc: 0.902051
# [9000]	training's auc: 0.948647	valid_1's auc: 0.902443
# [10000]	training's auc: 0.952034	valid_1's auc: 0.902491
# [11000]	training's auc: 0.955256	valid_1's auc: 0.902544
# [12000]	training's auc: 0.958392	valid_1's auc: 0.902614
# [13000]	training's auc: 0.961365	valid_1's auc: 0.902494
# [14000]	training's auc: 0.964162	valid_1's auc: 0.902596
# [15000]	training's auc: 0.966882	valid_1's auc: 0.902653
# [16000]	training's auc: 0.969434	valid_1's auc: 0.90258
# [17000]	training's auc: 0.971827	valid_1's auc: 0.90264
# [18000]	training's auc: 0.974075	valid_1's auc: 0.902594
# [19000]	training's auc: 0.976186	valid_1's auc: 0.902561
# Early stopping, best iteration is:
# [16469]	training's auc: 0.970571	valid_1's auc: 0.902711
# Fold 2
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.903161	valid_1's auc: 0.883382
# [2000]	training's auc: 0.914071	valid_1's auc: 0.891741
# [3000]	training's auc: 0.921739	valid_1's auc: 0.896336
# [4000]	training's auc: 0.9278	valid_1's auc: 0.898758
# [5000]	training's auc: 0.932868	valid_1's auc: 0.900156
# [6000]	training's auc: 0.937347	valid_1's auc: 0.901028
# [7000]	training's auc: 0.941404	valid_1's auc: 0.901437
# [8000]	training's auc: 0.945139	valid_1's auc: 0.901735
# [9000]	training's auc: 0.948736	valid_1's auc: 0.901741
# [10000]	training's auc: 0.952225	valid_1's auc: 0.901937
# [11000]	training's auc: 0.955485	valid_1's auc: 0.902047
# [12000]	training's auc: 0.958528	valid_1's auc: 0.901945
# [13000]	training's auc: 0.96142	valid_1's auc: 0.901795
# [14000]	training's auc: 0.964219	valid_1's auc: 0.901753
# Early stopping, best iteration is:
# [11146]	training's auc: 0.95595	valid_1's auc: 0.902136
# Fold 3
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.902985	valid_1's auc: 0.884944
# [2000]	training's auc: 0.913933	valid_1's auc: 0.893286
# [3000]	training's auc: 0.921722	valid_1's auc: 0.89737
# [4000]	training's auc: 0.927725	valid_1's auc: 0.899921
# [5000]	training's auc: 0.932809	valid_1's auc: 0.90138
# [6000]	training's auc: 0.937282	valid_1's auc: 0.90251
# [7000]	training's auc: 0.941375	valid_1's auc: 0.903172
# [8000]	training's auc: 0.945174	valid_1's auc: 0.903527
# [9000]	training's auc: 0.948787	valid_1's auc: 0.9038
# [10000]	training's auc: 0.952157	valid_1's auc: 0.903965
# [11000]	training's auc: 0.955319	valid_1's auc: 0.903895
# [12000]	training's auc: 0.958434	valid_1's auc: 0.903822
# Early stopping, best iteration is:
# [9856]	training's auc: 0.951695	valid_1's auc: 0.904013
# Fold 4
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.90236	valid_1's auc: 0.88798
# [2000]	training's auc: 0.913803	valid_1's auc: 0.89564
# [3000]	training's auc: 0.921707	valid_1's auc: 0.89993
# [4000]	training's auc: 0.927653	valid_1's auc: 0.902369
# [5000]	training's auc: 0.932768	valid_1's auc: 0.903959
# [6000]	training's auc: 0.937187	valid_1's auc: 0.90449
# [7000]	training's auc: 0.941214	valid_1's auc: 0.904911
# [8000]	training's auc: 0.944876	valid_1's auc: 0.905111
# [9000]	training's auc: 0.948498	valid_1's auc: 0.905321
# [10000]	training's auc: 0.951904	valid_1's auc: 0.905355
# [11000]	training's auc: 0.95514	valid_1's auc: 0.905197
# [12000]	training's auc: 0.958192	valid_1's auc: 0.9052
# Early stopping, best iteration is:
# [9766]	training's auc: 0.951107	valid_1's auc: 0.905455
# Fold 5
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.902455	valid_1's auc: 0.890487
# [2000]	training's auc: 0.913817	valid_1's auc: 0.898322
# [3000]	training's auc: 0.92139	valid_1's auc: 0.902393
# [4000]	training's auc: 0.927471	valid_1's auc: 0.904787
# [5000]	training's auc: 0.932663	valid_1's auc: 0.906106
# [6000]	training's auc: 0.937089	valid_1's auc: 0.906763
# [7000]	training's auc: 0.941124	valid_1's auc: 0.907193
# [8000]	training's auc: 0.944835	valid_1's auc: 0.907467
# [9000]	training's auc: 0.948497	valid_1's auc: 0.907558
# [10000]	training's auc: 0.951852	valid_1's auc: 0.907539
# [11000]	training's auc: 0.955123	valid_1's auc: 0.907492
# [12000]	training's auc: 0.958227	valid_1's auc: 0.907482
# Early stopping, best iteration is:
# [9325]	training's auc: 0.949576	valid_1's auc: 0.907633
# Fold 6
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.90293	valid_1's auc: 0.88118
# [2000]	training's auc: 0.914281	valid_1's auc: 0.889492
# [3000]	training's auc: 0.922244	valid_1's auc: 0.894261
# [4000]	training's auc: 0.928308	valid_1's auc: 0.896993
# [5000]	training's auc: 0.933341	valid_1's auc: 0.898465
# [6000]	training's auc: 0.93767	valid_1's auc: 0.899374
# [7000]	training's auc: 0.941655	valid_1's auc: 0.899913
# [8000]	training's auc: 0.945344	valid_1's auc: 0.900229
# [9000]	training's auc: 0.948917	valid_1's auc: 0.900592
# [10000]	training's auc: 0.952237	valid_1's auc: 0.900756
# [11000]	training's auc: 0.955418	valid_1's auc: 0.900763
# [12000]	training's auc: 0.958515	valid_1's auc: 0.900671
# [13000]	training's auc: 0.961413	valid_1's auc: 0.900632
# Early stopping, best iteration is:
# [10343]	training's auc: 0.953376	valid_1's auc: 0.900817
# Fold 7
# Training until validation scores don't improve for 3000 rounds.
# [1000]	training's auc: 0.902226	valid_1's auc: 0.887927
# [2000]	training's auc: 0.913635	valid_1's auc: 0.895316
# [3000]	training's auc: 0.921418	valid_1's auc: 0.899322
# [4000]	training's auc: 0.927458	valid_1's auc: 0.901556
# [5000]	training's auc: 0.932558	valid_1's auc: 0.902858
# [6000]	training's auc: 0.936929	valid_1's auc: 0.903703
# [7000]	training's auc: 0.940977	valid_1's auc: 0.903927
# [8000]	training's auc: 0.944818	valid_1's auc: 0.903917
# [9000]	training's auc: 0.948382	valid_1's auc: 0.904088
# [10000]	training's auc: 0.951736	valid_1's auc: 0.904116
# [11000]	training's auc: 0.955019	valid_1's auc: 0.904253
# [12000]	training's auc: 0.958106	valid_1's auc: 0.904204
# [13000]	training's auc: 0.961045	valid_1's auc: 0.904249
# Early stopping, best iteration is:
# [10867]	training's auc: 0.954598	valid_1's auc: 0.904335
# CV score: 0.90368

# %% [markdown]
# ## Ensemble two model

# %%
esemble_lgbm_cat = 0.5*oof_cb+0.5*oof
print('LightBGM auc = {:<8.5f}'.format(roc_auc_score(train_target, oof)))
print('catboost auc = {:<8.5f}'.format(roc_auc_score(train_target, oof_cb)))
print('LightBGM+catboost auc = {:<8.5f}'.format(roc_auc_score(train_target, esemble_lgbm_cat)))
# Out:
# LightBGM auc = 0.90368
# catboost auc = 0.91384
# LightBGM+catboost auc = 0.91033

# %%
esemble_pred_lgbm_cat = 0.5*predictions+0.5*predictions_cb

# %%
id_code_test = test['ID_code']

# %% [markdown]
# ## Submissions

# %%
my_submission_lbgm = pd.DataFrame({"ID_code" : id_code_test, "target" : predictions})
my_submission_cat = pd.DataFrame({"ID_code" : id_code_test, "target" : predictions_cb})
my_submission_esemble_lgbm_cat = pd.DataFrame({"ID_code" : id_code_test, "target" : esemble_pred_lgbm_cat})

# %%
my_submission_lbgm.to_csv('submission_lbgm.csv', index = False, header = True)
my_submission_cat.to_csv('submission_cb.csv', index = False, header = True)
my_submission_esemble_lgbm_cat.to_csv('my_submission_esemble_lgbm_cat.csv', index = False, header = True)

# %% [markdown]
# ### LightGBM
# * Fine tune parameters (0.898 to 0.899)
#
# ### Ensemble LightGBM and catboost
# * Leaderboard Scores:
#   - Public: 0.90215
#   - Private: 0.90083
